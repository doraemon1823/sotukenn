# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys,os

df=pd.read_csv("B-id_friends_01251100.csv")
df=df[1:]
df=df.drop("Unnamed: 0",axis=1)
df=df.reset_index()
df=df.drop("index",axis=1)
list_a = list(range(201))
df.columns=list_a

# %%
df.shape
# Out:
# (450, 201)

# %%
ID=df[0]
id_num=0
list_edge=[]
print("START !!!!")
for loc_num in range(449):
    #loc_num=500+loc_num
    print(loc_num,"/1000")
    for next_num in range(200):
        for id_num in range(449):
            if df.loc[loc_num][next_num+1]==ID[id_num]:
                print(loc_num,"==like=>>",id_num)
                case=([loc_num,id_num])
                list_edge.append(case)
            else:
                pass
# Out:
# START !!!!
# 0 /1000
# 0 ==like=>> 109
# 0 ==like=>> 252
# 0 ==like=>> 417
# 0 ==like=>> 49
# 0 ==like=>> 446
# 0 ==like=>> 318
# 0 ==like=>> 41
# 0 ==like=>> 162
# 0 ==like=>> 22
# 0 ==like=>> 241
# 0 ==like=>> 316
# 0 ==like=>> 217
# 1 /1000
# 1 ==like=>> 78
# 1 ==like=>> 265
# 1 ==like=>> 25
# 2 /1000
# 2 ==like=>> 442
# 2 ==like=>> 321
# 3 /1000
# 3 ==like=>> 355
# 3 ==like=>> 147
# 4 /1000
# 4 ==like=>> 202
# 4 ==like=>> 169
# 4 ==like=>> 114
# 5 /1000
# 5 ==like=>> 71
# 5 ==like=>> 173
# 6 /1000
# 6 ==like=>> 118
# 6 ==like=>> 313
# 6 ==like=>> 423
# 6 ==like=>> 303
# 7 /1000
# 7 ==like=>> 302
# 7 ==like=>> 258
# 7 ==like=>> 324
# 8 /1000
# 8 ==like=>> 41
# 8 ==like=>> 115
# 8 ==like=>> 407
# 8 ==like=>> 349
# 8 ==like=>> 397
# 9 /1000
# 9 ==like=>> 97
# 9 ==like=>> 262
# 9 ==like=>> 31
# 9 ==like=>> 438
# 9 ==like=>> 108
# 9 ==like=>> 141
# 10 /1000
# 10 ==like=>> 162
# 10 ==like=>> 109
# 10 ==like=>> 22
# 10 ==like=>> 115
# 10 ==like=>> 423
# 10 ==like=>> 173
# 10 ==like=>> 55
# 10 ==like=>> 186
# 10 ==like=>> 76
# 10 ==like=>> 88
# 10 ==like=>> 316
# 11 /1000
# 11 ==like=>> 74
# 11 ==like=>> 203
# 11 ==like=>> 252
# 11 ==like=>> 88
# 11 ==like=>> 424
# 11 ==like=>> 149
# 11 ==like=>> 241
# 12 /1000
# 13 /1000
# 14 /1000
# 15 /1000
# 15 ==like=>> 345
# 15 ==like=>> 191
# 15 ==like=>> 389
# 15 ==like=>> 36
# 16 /1000
# 16 ==like=>> 448
# 17 /1000
# 17 ==like=>> 53
# 17 ==like=>> 185
# 18 /1000
# 18 ==like=>> 205
# 19 /1000
# 19 ==like=>> 291
# 19 ==like=>> 162
# 19 ==like=>> 89
# 20 /1000
# 20 ==like=>> 57
# 20 ==like=>> 416
# 20 ==like=>> 152
# 20 ==like=>> 427
# 20 ==like=>> 86
# 20 ==like=>> 299
# 20 ==like=>> 130
# 20 ==like=>> 328
# 21 /1000
# 21 ==like=>> 55
# 21 ==like=>> 186
# 22 /1000
# 23 /1000
# 24 /1000
# 25 /1000
# 26 /1000
# 26 ==like=>> 302
# 26 ==like=>> 301
# 26 ==like=>> 147
# 26 ==like=>> 279
# 26 ==like=>> 4
# 26 ==like=>> 334
# 26 ==like=>> 246
# 27 /1000
# 28 /1000
# 29 /1000
# 29 ==like=>> 431
# 29 ==like=>> 253
# 30 /1000
# 30 ==like=>> 63
# 30 ==like=>> 22
# 30 ==like=>> 162
# 31 /1000
# 31 ==like=>> 130
# 31 ==like=>> 361
# 31 ==like=>> 339
# 31 ==like=>> 196
# 31 ==like=>> 9
# 32 /1000
# 32 ==like=>> 55
# 33 /1000
# 33 ==like=>> 74
# 33 ==like=>> 203
# 33 ==like=>> 314
# 33 ==like=>> 252
# 33 ==like=>> 49
# 33 ==like=>> 446
# 33 ==like=>> 263
# 34 /1000
# 35 /1000
# 35 ==like=>> 290
# 36 /1000
# 36 ==like=>> 15
# 36 ==like=>> 333
# 36 ==like=>> 256
# 36 ==like=>> 234
# 36 ==like=>> 80
# 36 ==like=>> 202
# 37 /1000
# 37 ==like=>> 312
# 37 ==like=>> 147
# 37 ==like=>> 180
# 37 ==like=>> 81
# 37 ==like=>> 290
# 37 ==like=>> 246
# 37 ==like=>> 70
# 38 /1000
# 39 /1000
# 39 ==like=>> 173
# 39 ==like=>> 313
# 40 /1000
# 40 ==like=>> 302
# 41 /1000
# 41 ==like=>> 162
# 41 ==like=>> 318
# 41 ==like=>> 0
# 41 ==like=>> 63
# 41 ==like=>> 115
# 41 ==like=>> 206
# 41 ==like=>> 8
# 41 ==like=>> 74
# 41 ==like=>> 316
# 42 /1000
# 42 ==like=>> 130
# 42 ==like=>> 328
# 42 ==like=>> 361
# 43 /1000
# 43 ==like=>> 263
# 44 /1000
# 45 /1000
# 46 /1000
# 47 /1000
# 47 ==like=>> 147
# 47 ==like=>> 302
# 47 ==like=>> 14
# 47 ==like=>> 58
# 47 ==like=>> 333
# 47 ==like=>> 124
# 47 ==like=>> 245
# 47 ==like=>> 388
# 47 ==like=>> 234
# 47 ==like=>> 80
# 47 ==like=>> 212
# 48 /1000
# 48 ==like=>> 16
# 48 ==like=>> 301
# 48 ==like=>> 367
# 48 ==like=>> 378
# 48 ==like=>> 410
# 49 /1000
# 49 ==like=>> 241
# 49 ==like=>> 362
# 49 ==like=>> 373
# 49 ==like=>> 307
# 49 ==like=>> 0
# 49 ==like=>> 294
# 49 ==like=>> 162
# 49 ==like=>> 88
# 49 ==like=>> 33
# 49 ==like=>> 173
# 49 ==like=>> 22
# 49 ==like=>> 316
# 50 /1000
# 50 ==like=>> 118
# 51 /1000
# 51 ==like=>> 313
# 52 /1000
# 53 /1000
# 53 ==like=>> 72
# 53 ==like=>> 287
# 53 ==like=>> 185
# 54 /1000
# 54 ==like=>> 263
# 54 ==like=>> 55
# 54 ==like=>> 186
# 54 ==like=>> 43
# 55 /1000
# 55 ==like=>> 10
# 55 ==like=>> 21
# 55 ==like=>> 32
# 55 ==like=>> 43
# 55 ==like=>> 54
# 55 ==like=>> 65
# 55 ==like=>> 76
# 55 ==like=>> 109
# 55 ==like=>> 120
# 55 ==like=>> 153
# 55 ==like=>> 164
# 55 ==like=>> 175
# 55 ==like=>> 186
# 55 ==like=>> 197
# 55 ==like=>> 208
# 55 ==like=>> 241
# 55 ==like=>> 252
# 55 ==like=>> 263
# 55 ==like=>> 274
# 55 ==like=>> 285
# 55 ==like=>> 296
# 55 ==like=>> 307
# 55 ==like=>> 318
# 55 ==like=>> 329
# 55 ==like=>> 340
# 55 ==like=>> 362
# 55 ==like=>> 373
# 55 ==like=>> 384
# 55 ==like=>> 395
# 55 ==like=>> 406
# 55 ==like=>> 417
# 55 ==like=>> 439
# 55 ==like=>> 63
# 55 ==like=>> 162
# 55 ==like=>> 179
# 56 /1000
# 56 ==like=>> 221
# 57 /1000
# 57 ==like=>> 313
# 57 ==like=>> 46
# 58 /1000
# 58 ==like=>> 366
# 58 ==like=>> 377
# 58 ==like=>> 80
# 58 ==like=>> 47
# 58 ==like=>> 168
# 58 ==like=>> 14
# 58 ==like=>> 333
# 58 ==like=>> 421
# 58 ==like=>> 344
# 58 ==like=>> 135
# 58 ==like=>> 256
# 58 ==like=>> 322
# 58 ==like=>> 157
# 58 ==like=>> 311
# 58 ==like=>> 124
# 58 ==like=>> 201
# 58 ==like=>> 212
# 59 /1000
# 59 ==like=>> 4
# 59 ==like=>> 246
# 59 ==like=>> 213
# 59 ==like=>> 103
# 59 ==like=>> 334
# 59 ==like=>> 114
# 59 ==like=>> 301
# 59 ==like=>> 312
# 59 ==like=>> 92
# 59 ==like=>> 290
# 59 ==like=>> 345
# 59 ==like=>> 367
# 59 ==like=>> 378
# 59 ==like=>> 169
# 59 ==like=>> 147
# 60 /1000
# 61 /1000
# 61 ==like=>> 171
# 61 ==like=>> 314
# 62 /1000
# 62 ==like=>> 349
# 62 ==like=>> 397
# 62 ==like=>> 56
# 63 /1000
# 64 /1000
# 64 ==like=>> 119
# 64 ==like=>> 317
# 65 /1000
# 66 /1000
# 66 ==like=>> 56
# 66 ==like=>> 173
# 66 ==like=>> 307
# 66 ==like=>> 349
# 66 ==like=>> 397
# 66 ==like=>> 77
# 66 ==like=>> 22
# 67 /1000
# 67 ==like=>> 16
# 68 /1000
# 69 /1000
# 69 ==like=>> 334
# 69 ==like=>> 302
# 69 ==like=>> 4
# 69 ==like=>> 256
# 69 ==like=>> 421
# 69 ==like=>> 333
# 69 ==like=>> 80
# 69 ==like=>> 245
# 69 ==like=>> 157
# 69 ==like=>> 147
# 69 ==like=>> 168
# 69 ==like=>> 201
# 69 ==like=>> 36
# 69 ==like=>> 388
# 69 ==like=>> 91
# 69 ==like=>> 135
# 69 ==like=>> 102
# 69 ==like=>> 179
# 70 /1000
# 70 ==like=>> 444
# 70 ==like=>> 191
# 70 ==like=>> 290
# 70 ==like=>> 279
# 70 ==like=>> 246
# 70 ==like=>> 147
# 70 ==like=>> 37
# 70 ==like=>> 224
# 70 ==like=>> 158
# 71 /1000
# 71 ==like=>> 5
# 71 ==like=>> 173
# 72 /1000
# 72 ==like=>> 38
# 72 ==like=>> 369
# 72 ==like=>> 380
# 72 ==like=>> 53
# 73 /1000
# 74 /1000
# 74 ==like=>> 66
# 74 ==like=>> 33
# 74 ==like=>> 88
# 74 ==like=>> 338
# 74 ==like=>> 228
# 74 ==like=>> 173
# 74 ==like=>> 349
# 74 ==like=>> 397
# 75 /1000
# 75 ==like=>> 174
# 75 ==like=>> 306
# 75 ==like=>> 317
# 76 /1000
# 77 /1000
# 77 ==like=>> 109
# 77 ==like=>> 252
# 77 ==like=>> 263
# 77 ==like=>> 149
# 78 /1000
# 78 ==like=>> 313
# 78 ==like=>> 89
# 78 ==like=>> 247
# 78 ==like=>> 265
# 78 ==like=>> 133
# 78 ==like=>> 276
# 79 /1000
# 80 /1000
# 80 ==like=>> 366
# 80 ==like=>> 377
# 80 ==like=>> 58
# 80 ==like=>> 147
# 80 ==like=>> 388
# 80 ==like=>> 245
# 80 ==like=>> 432
# 80 ==like=>> 14
# 80 ==like=>> 102
# 80 ==like=>> 344
# 80 ==like=>> 421
# 80 ==like=>> 212
# 80 ==like=>> 124
# 80 ==like=>> 333
# 80 ==like=>> 157
# 80 ==like=>> 234
# 80 ==like=>> 201
# 80 ==like=>> 355
# 80 ==like=>> 311
# 80 ==like=>> 47
# 80 ==like=>> 135
# 80 ==like=>> 399
# 80 ==like=>> 91
# 80 ==like=>> 69
# 80 ==like=>> 278
# 80 ==like=>> 36
# 80 ==like=>> 322
# 80 ==like=>> 168
# 80 ==like=>> 179
# 80 ==like=>> 256
# 81 /1000
# 81 ==like=>> 191
# 81 ==like=>> 37
# 81 ==like=>> 147
# 81 ==like=>> 169
# 81 ==like=>> 179
# 81 ==like=>> 235
# 81 ==like=>> 345
# 81 ==like=>> 213
# 81 ==like=>> 125
# 81 ==like=>> 334
# 81 ==like=>> 59
# 81 ==like=>> 246
# 81 ==like=>> 268
# 81 ==like=>> 92
# 81 ==like=>> 290
# 81 ==like=>> 367
# 81 ==like=>> 378
# 81 ==like=>> 312
# 81 ==like=>> 301
# 82 /1000
# 82 ==like=>> 225
# 83 /1000
# 83 ==like=>> 425
# 83 ==like=>> 316
# 83 ==like=>> 118
# 83 ==like=>> 303
# 83 ==like=>> 173
# 83 ==like=>> 171
# 84 /1000
# 85 /1000
# 86 /1000
# 86 ==like=>> 361
# 87 /1000
# 88 /1000
# 88 ==like=>> 74
# 88 ==like=>> 203
# 88 ==like=>> 327
# 88 ==like=>> 329
# 88 ==like=>> 423
# 88 ==like=>> 424
# 88 ==like=>> 241
# 88 ==like=>> 252
# 89 /1000
# 90 /1000
# 90 ==like=>> 35
# 91 /1000
# 91 ==like=>> 313
# 91 ==like=>> 302
# 91 ==like=>> 399
# 91 ==like=>> 124
# 91 ==like=>> 421
# 91 ==like=>> 333
# 91 ==like=>> 80
# 91 ==like=>> 388
# 91 ==like=>> 179
# 91 ==like=>> 69
# 91 ==like=>> 256
# 91 ==like=>> 157
# 91 ==like=>> 47
# 91 ==like=>> 36
# 91 ==like=>> 322
# 91 ==like=>> 366
# 91 ==like=>> 377
# 91 ==like=>> 135
# 91 ==like=>> 311
# 91 ==like=>> 168
# 92 /1000
# 92 ==like=>> 444
# 92 ==like=>> 81
# 92 ==like=>> 301
# 92 ==like=>> 125
# 92 ==like=>> 191
# 92 ==like=>> 235
# 92 ==like=>> 59
# 92 ==like=>> 312
# 92 ==like=>> 268
# 92 ==like=>> 290
# 92 ==like=>> 345
# 92 ==like=>> 367
# 92 ==like=>> 378
# 92 ==like=>> 224
# 92 ==like=>> 169
# 92 ==like=>> 355
# 92 ==like=>> 147
# 93 /1000
# 93 ==like=>> 241
# 93 ==like=>> 84
# 94 /1000
# 94 ==like=>> 185
# 95 /1000
# 95 ==like=>> 323
# 95 ==like=>> 268
# 96 /1000
# 97 /1000
# 97 ==like=>> 416
# 97 ==like=>> 196
# 97 ==like=>> 427
# 97 ==like=>> 361
# 97 ==like=>> 108
# 97 ==like=>> 328
# 98 /1000
# 98 ==like=>> 77
# 98 ==like=>> 241
# 98 ==like=>> 72
# 98 ==like=>> 22
# 98 ==like=>> 33
# 98 ==like=>> 66
# 98 ==like=>> 55
# 98 ==like=>> 88
# 98 ==like=>> 115
# 98 ==like=>> 316
# 99 /1000
# 99 ==like=>> 89
# 99 ==like=>> 263
# 100 /1000
# 101 /1000
# 101 ==like=>> 112
# 102 /1000
# 102 ==like=>> 302
# 102 ==like=>> 432
# 102 ==like=>> 147
# 102 ==like=>> 399
# 102 ==like=>> 14
# 102 ==like=>> 256
# 102 ==like=>> 80
# 102 ==like=>> 157
# 102 ==like=>> 344
# 102 ==like=>> 168
# 102 ==like=>> 124
# 102 ==like=>> 201
# 102 ==like=>> 421
# 102 ==like=>> 333
# 102 ==like=>> 3
# 102 ==like=>> 234
# 102 ==like=>> 47
# 102 ==like=>> 322
# 102 ==like=>> 69
# 103 /1000
# 104 /1000
# 104 ==like=>> 173
# 104 ==like=>> 424
# 104 ==like=>> 303
# 105 /1000
# 105 ==like=>> 263
# 106 /1000
# 107 /1000
# 107 ==like=>> 203
# 107 ==like=>> 302
# 107 ==like=>> 252
# 107 ==like=>> 72
# 107 ==like=>> 263
# 107 ==like=>> 49
# 107 ==like=>> 446
# 108 /1000
# 108 ==like=>> 251
# 109 /1000
# 109 ==like=>> 10
# 109 ==like=>> 302
# 109 ==like=>> 274
# 109 ==like=>> 191
# 109 ==like=>> 299
# 109 ==like=>> 173
# 109 ==like=>> 407
# 109 ==like=>> 66
# 109 ==like=>> 217
# 110 /1000
# 110 ==like=>> 313
# 111 /1000
# 112 /1000
# 112 ==like=>> 302
# 113 /1000
# 113 ==like=>> 245
# 113 ==like=>> 36
# 113 ==like=>> 25
# 113 ==like=>> 302
# 113 ==like=>> 135
# 113 ==like=>> 311
# 113 ==like=>> 267
# 113 ==like=>> 399
# 113 ==like=>> 322
# 113 ==like=>> 355
# 113 ==like=>> 168
# 113 ==like=>> 333
# 113 ==like=>> 58
# 113 ==like=>> 80
# 114 /1000
# 114 ==like=>> 312
# 114 ==like=>> 389
# 114 ==like=>> 103
# 114 ==like=>> 59
# 115 /1000
# 115 ==like=>> 10
# 115 ==like=>> 203
# 115 ==like=>> 302
# 115 ==like=>> 109
# 115 ==like=>> 63
# 115 ==like=>> 252
# 116 /1000
# 116 ==like=>> 241
# 116 ==like=>> 302
# 117 /1000
# 117 ==like=>> 442
# 117 ==like=>> 288
# 118 /1000
# 118 ==like=>> 226
# 118 ==like=>> 83
# 119 /1000
# 120 /1000
# 120 ==like=>> 55
# 120 ==like=>> 162
# 120 ==like=>> 115
# 120 ==like=>> 241
# 121 /1000
# 122 /1000
# 122 ==like=>> 313
# 122 ==like=>> 302
# 122 ==like=>> 144
# 122 ==like=>> 287
# 123 /1000
# 124 /1000
# 124 ==like=>> 302
# 124 ==like=>> 411
# 124 ==like=>> 136
# 124 ==like=>> 125
# 124 ==like=>> 80
# 124 ==like=>> 344
# 124 ==like=>> 113
# 124 ==like=>> 201
# 124 ==like=>> 91
# 124 ==like=>> 421
# 124 ==like=>> 322
# 124 ==like=>> 256
# 124 ==like=>> 333
# 124 ==like=>> 58
# 124 ==like=>> 399
# 124 ==like=>> 102
# 124 ==like=>> 179
# 124 ==like=>> 212
# 124 ==like=>> 47
# 124 ==like=>> 311
# 124 ==like=>> 223
# 125 /1000
# 125 ==like=>> 81
# 125 ==like=>> 333
# 125 ==like=>> 201
# 125 ==like=>> 179
# 125 ==like=>> 411
# 125 ==like=>> 323
# 125 ==like=>> 322
# 125 ==like=>> 312
# 125 ==like=>> 92
# 125 ==like=>> 355
# 125 ==like=>> 257
# 125 ==like=>> 124
# 125 ==like=>> 47
# 125 ==like=>> 421
# 125 ==like=>> 4
# 126 /1000
# 127 /1000
# 128 /1000
# 128 ==like=>> 302
# 128 ==like=>> 241
# 128 ==like=>> 340
# 129 /1000
# 129 ==like=>> 303
# 130 /1000
# 130 ==like=>> 361
# 130 ==like=>> 97
# 130 ==like=>> 42
# 130 ==like=>> 31
# 131 /1000
# 131 ==like=>> 302
# 131 ==like=>> 55
# 131 ==like=>> 16
# 131 ==like=>> 314
# 132 /1000
# 132 ==like=>> 16
# 133 /1000
# 134 /1000
# 134 ==like=>> 189
# 134 ==like=>> 385
# 134 ==like=>> 112
# 134 ==like=>> 302
# 135 /1000
# 135 ==like=>> 345
# 135 ==like=>> 14
# 135 ==like=>> 256
# 135 ==like=>> 80
# 135 ==like=>> 147
# 135 ==like=>> 58
# 135 ==like=>> 333
# 135 ==like=>> 234
# 135 ==like=>> 168
# 135 ==like=>> 421
# 135 ==like=>> 179
# 135 ==like=>> 157
# 135 ==like=>> 201
# 135 ==like=>> 36
# 135 ==like=>> 322
# 135 ==like=>> 102
# 135 ==like=>> 69
# 135 ==like=>> 366
# 135 ==like=>> 377
# 135 ==like=>> 91
# 135 ==like=>> 355
# 135 ==like=>> 47
# 135 ==like=>> 223
# 135 ==like=>> 311
# 136 /1000
# 136 ==like=>> 302
# 136 ==like=>> 103
# 136 ==like=>> 246
# 136 ==like=>> 279
# 136 ==like=>> 124
# 136 ==like=>> 367
# 136 ==like=>> 378
# 136 ==like=>> 432
# 136 ==like=>> 235
# 136 ==like=>> 4
# 136 ==like=>> 147
# 137 /1000
# 138 /1000
# 139 /1000
# 139 ==like=>> 302
# 139 ==like=>> 447
# 139 ==like=>> 359
# 140 /1000
# 141 /1000
# 141 ==like=>> 273
# 141 ==like=>> 416
# 141 ==like=>> 306
# 141 ==like=>> 152
# 141 ==like=>> 9
# 141 ==like=>> 130
# 141 ==like=>> 218
# 142 /1000
# 143 /1000
# 143 ==like=>> 132
# 144 /1000
# 145 /1000
# 146 /1000
# 146 ==like=>> 302
# 147 /1000
# 147 ==like=>> 190
# 147 ==like=>> 158
# 147 ==like=>> 47
# 147 ==like=>> 213
# 147 ==like=>> 26
# 147 ==like=>> 367
# 147 ==like=>> 378
# 147 ==like=>> 92
# 148 /1000
# 149 /1000
# 149 ==like=>> 115
# 149 ==like=>> 203
# 149 ==like=>> 263
# 150 /1000
# 150 ==like=>> 16
# 151 /1000
# 152 /1000
# 152 ==like=>> 273
# 152 ==like=>> 20
# 152 ==like=>> 64
# 152 ==like=>> 42
# 152 ==like=>> 141
# 153 /1000
# 153 ==like=>> 55
# 154 /1000
# 154 ==like=>> 302
# 155 /1000
# 156 /1000
# 156 ==like=>> 145
# 157 /1000
# 157 ==like=>> 245
# 157 ==like=>> 256
# 157 ==like=>> 80
# 157 ==like=>> 333
# 157 ==like=>> 102
# 157 ==like=>> 421
# 157 ==like=>> 234
# 157 ==like=>> 14
# 157 ==like=>> 69
# 157 ==like=>> 58
# 157 ==like=>> 168
# 157 ==like=>> 179
# 157 ==like=>> 322
# 157 ==like=>> 91
# 157 ==like=>> 36
# 157 ==like=>> 201
# 157 ==like=>> 311
# 157 ==like=>> 135
# 157 ==like=>> 47
# 158 /1000
# 158 ==like=>> 213
# 158 ==like=>> 444
# 158 ==like=>> 246
# 158 ==like=>> 279
# 158 ==like=>> 147
# 158 ==like=>> 389
# 158 ==like=>> 268
# 158 ==like=>> 59
# 158 ==like=>> 70
# 159 /1000
# 159 ==like=>> 38
# 160 /1000
# 160 ==like=>> 16
# 160 ==like=>> 448
# 161 /1000
# 161 ==like=>> 447
# 162 /1000
# 162 ==like=>> 10
# 162 ==like=>> 41
# 162 ==like=>> 203
# 162 ==like=>> 423
# 162 ==like=>> 30
# 162 ==like=>> 252
# 162 ==like=>> 407
# 162 ==like=>> 272
# 162 ==like=>> 49
# 162 ==like=>> 446
# 163 /1000
# 164 /1000
# 165 /1000
# 165 ==like=>> 302
# 166 /1000
# 167 /1000
# 168 /1000
# 168 ==like=>> 313
# 168 ==like=>> 411
# 168 ==like=>> 345
# 168 ==like=>> 367
# 168 ==like=>> 378
# 168 ==like=>> 4
# 168 ==like=>> 169
# 169 /1000
# 169 ==like=>> 191
# 169 ==like=>> 92
# 169 ==like=>> 312
# 169 ==like=>> 59
# 170 /1000
# 170 ==like=>> 181
# 171 /1000
# 171 ==like=>> 61
# 171 ==like=>> 83
# 171 ==like=>> 391
# 171 ==like=>> 38
# 172 /1000
# 173 /1000
# 173 ==like=>> 357
# 173 ==like=>> 39
# 173 ==like=>> 38
# 173 ==like=>> 203
# 173 ==like=>> 71
# 173 ==like=>> 402
# 173 ==like=>> 74
# 173 ==like=>> 292
# 174 /1000
# 174 ==like=>> 20
# 174 ==like=>> 75
# 174 ==like=>> 361
# 174 ==like=>> 302
# 175 /1000
# 175 ==like=>> 55
# 175 ==like=>> 186
# 175 ==like=>> 208
# 176 /1000
# 177 /1000
# 178 /1000
# 178 ==like=>> 321
# 178 ==like=>> 13
# 179 /1000
# 179 ==like=>> 113
# 179 ==like=>> 302
# 179 ==like=>> 124
# 179 ==like=>> 212
# 179 ==like=>> 14
# 179 ==like=>> 256
# 180 /1000
# 180 ==like=>> 202
# 180 ==like=>> 246
# 180 ==like=>> 37
# 180 ==like=>> 4
# 180 ==like=>> 355
# 180 ==like=>> 125
# 180 ==like=>> 290
# 181 /1000
# 181 ==like=>> 170
# 182 /1000
# 183 /1000
# 184 /1000
# 185 /1000
# 185 ==like=>> 402
# 186 /1000
# 186 ==like=>> 237
# 186 ==like=>> 38
# 186 ==like=>> 10
# 186 ==like=>> 55
# 187 /1000
# 188 /1000
# 188 ==like=>> 55
# 188 ==like=>> 221
# 189 /1000
# 190 /1000
# 190 ==like=>> 290
# 191 /1000
# 191 ==like=>> 302
# 191 ==like=>> 169
# 191 ==like=>> 444
# 191 ==like=>> 81
# 191 ==like=>> 70
# 191 ==like=>> 334
# 191 ==like=>> 15
# 191 ==like=>> 92
# 191 ==like=>> 312
# 191 ==like=>> 213
# 191 ==like=>> 389
# 191 ==like=>> 268
# 191 ==like=>> 246
# 191 ==like=>> 367
# 191 ==like=>> 378
# 191 ==like=>> 290
# 191 ==like=>> 48
# 191 ==like=>> 433
# 192 /1000
# 193 /1000
# 193 ==like=>> 185
# 194 /1000
# 195 /1000
# 195 ==like=>> 371
# 195 ==like=>> 382
# 195 ==like=>> 184
# 195 ==like=>> 349
# 195 ==like=>> 397
# 195 ==like=>> 140
# 195 ==like=>> 338
# 196 /1000
# 196 ==like=>> 20
# 196 ==like=>> 361
# 196 ==like=>> 306
# 196 ==like=>> 31
# 197 /1000
# 198 /1000
# 199 /1000
# 199 ==like=>> 78
# 199 ==like=>> 210
# 200 /1000
# 201 /1000
# 201 ==like=>> 125
# 202 /1000
# 202 ==like=>> 4
# 202 ==like=>> 313
# 202 ==like=>> 48
# 202 ==like=>> 410
# 202 ==like=>> 302
# 202 ==like=>> 60
# 203 /1000
# 204 /1000
# 204 ==like=>> 340
# 204 ==like=>> 281
# 204 ==like=>> 349
# 204 ==like=>> 397
# 205 /1000
# 205 ==like=>> 309
# 206 /1000
# 207 /1000
# 207 ==like=>> 86
# 208 /1000
# 209 /1000
# 209 ==like=>> 57
# 210 /1000
# 210 ==like=>> 38
# 210 ==like=>> 280
# 210 ==like=>> 299
# 211 /1000
# 212 /1000
# 212 ==like=>> 179
# 212 ==like=>> 278
# 212 ==like=>> 80
# 212 ==like=>> 267
# 212 ==like=>> 344
# 212 ==like=>> 366
# 212 ==like=>> 377
# 212 ==like=>> 333
# 212 ==like=>> 256
# 212 ==like=>> 399
# 212 ==like=>> 168
# 212 ==like=>> 322
# 212 ==like=>> 113
# 212 ==like=>> 124
# 212 ==like=>> 58
# 212 ==like=>> 201
# 212 ==like=>> 91
# 212 ==like=>> 421
# 212 ==like=>> 47
# 213 /1000
# 213 ==like=>> 246
# 213 ==like=>> 59
# 213 ==like=>> 158
# 213 ==like=>> 444
# 213 ==like=>> 290
# 213 ==like=>> 191
# 213 ==like=>> 147
# 213 ==like=>> 389
# 213 ==like=>> 81
# 213 ==like=>> 301
# 213 ==like=>> 433
# 213 ==like=>> 312
# 213 ==like=>> 114
# 213 ==like=>> 367
# 213 ==like=>> 378
# 214 /1000
# 214 ==like=>> 263
# 214 ==like=>> 72
# 215 /1000
# 216 /1000
# 216 ==like=>> 281
# 217 /1000
# 217 ==like=>> 302
# 217 ==like=>> 109
# 217 ==like=>> 56
# 217 ==like=>> 206
# 217 ==like=>> 162
# 217 ==like=>> 0
# 217 ==like=>> 349
# 217 ==like=>> 397
# 218 /1000
# 219 /1000
# 219 ==like=>> 55
# 219 ==like=>> 23
# 219 ==like=>> 276
# 220 /1000
# 220 ==like=>> 237
# 221 /1000
# 221 ==like=>> 56
# 221 ==like=>> 321
# 222 /1000
# 223 /1000
# 223 ==like=>> 47
# 223 ==like=>> 124
# 223 ==like=>> 234
# 223 ==like=>> 3
# 223 ==like=>> 102
# 223 ==like=>> 366
# 223 ==like=>> 377
# 223 ==like=>> 69
# 223 ==like=>> 135
# 224 /1000
# 224 ==like=>> 444
# 224 ==like=>> 191
# 224 ==like=>> 312
# 224 ==like=>> 15
# 224 ==like=>> 389
# 224 ==like=>> 334
# 224 ==like=>> 246
# 224 ==like=>> 367
# 224 ==like=>> 378
# 224 ==like=>> 290
# 224 ==like=>> 92
# 224 ==like=>> 268
# 224 ==like=>> 70
# 225 /1000
# 225 ==like=>> 313
# 226 /1000
# 226 ==like=>> 118
# 227 /1000
# 227 ==like=>> 89
# 228 /1000
# 228 ==like=>> 74
# 228 ==like=>> 316
# 228 ==like=>> 33
# 228 ==like=>> 206
# 229 /1000
# 229 ==like=>> 251
# 229 ==like=>> 427
# 229 ==like=>> 350
# 229 ==like=>> 218
# 229 ==like=>> 31
# 230 /1000
# 230 ==like=>> 302
# 230 ==like=>> 43
# 230 ==like=>> 55
# 230 ==like=>> 89
# 231 /1000
# 231 ==like=>> 43
# 231 ==like=>> 208
# 231 ==like=>> 186
# 231 ==like=>> 63
# 232 /1000
# 233 /1000
# 234 /1000
# 234 ==like=>> 168
# 234 ==like=>> 201
# 234 ==like=>> 36
# 234 ==like=>> 14
# 234 ==like=>> 80
# 234 ==like=>> 157
# 234 ==like=>> 366
# 234 ==like=>> 377
# 234 ==like=>> 333
# 234 ==like=>> 399
# 234 ==like=>> 3
# 234 ==like=>> 421
# 234 ==like=>> 256
# 234 ==like=>> 311
# 234 ==like=>> 135
# 234 ==like=>> 322
# 234 ==like=>> 179
# 234 ==like=>> 102
# 234 ==like=>> 432
# 234 ==like=>> 47
# 235 /1000
# 235 ==like=>> 103
# 235 ==like=>> 114
# 235 ==like=>> 312
# 235 ==like=>> 334
# 235 ==like=>> 48
# 235 ==like=>> 301
# 235 ==like=>> 345
# 235 ==like=>> 367
# 235 ==like=>> 378
# 235 ==like=>> 136
# 235 ==like=>> 146
# 235 ==like=>> 302
# 236 /1000
# 237 /1000
# 237 ==like=>> 220
# 238 /1000
# 239 /1000
# 240 /1000
# 241 /1000
# 241 ==like=>> 116
# 241 ==like=>> 49
# 241 ==like=>> 446
# 241 ==like=>> 93
# 242 /1000
# 243 /1000
# 243 ==like=>> 302
# 243 ==like=>> 16
# 244 /1000
# 245 /1000
# 245 ==like=>> 410
# 245 ==like=>> 157
# 245 ==like=>> 3
# 245 ==like=>> 146
# 245 ==like=>> 201
# 245 ==like=>> 366
# 245 ==like=>> 377
# 245 ==like=>> 421
# 245 ==like=>> 147
# 245 ==like=>> 355
# 245 ==like=>> 322
# 245 ==like=>> 69
# 245 ==like=>> 432
# 246 /1000
# 246 ==like=>> 213
# 246 ==like=>> 158
# 246 ==like=>> 268
# 246 ==like=>> 180
# 246 ==like=>> 26
# 246 ==like=>> 224
# 246 ==like=>> 136
# 246 ==like=>> 81
# 246 ==like=>> 191
# 246 ==like=>> 312
# 246 ==like=>> 301
# 246 ==like=>> 334
# 246 ==like=>> 37
# 246 ==like=>> 367
# 246 ==like=>> 378
# 246 ==like=>> 389
# 246 ==like=>> 147
# 246 ==like=>> 279
# 246 ==like=>> 290
# 247 /1000
# 248 /1000
# 248 ==like=>> 302
# 248 ==like=>> 313
# 248 ==like=>> 299
# 249 /1000
# 249 ==like=>> 313
# 250 /1000
# 250 ==like=>> 303
# 250 ==like=>> 349
# 250 ==like=>> 397
# 251 /1000
# 252 /1000
# 252 ==like=>> 203
# 252 ==like=>> 82
# 252 ==like=>> 76
# 252 ==like=>> 49
# 252 ==like=>> 446
# 252 ==like=>> 55
# 252 ==like=>> 423
# 252 ==like=>> 173
# 252 ==like=>> 241
# 252 ==like=>> 407
# 253 /1000
# 254 /1000
# 254 ==like=>> 276
# 255 /1000
# 256 /1000
# 256 ==like=>> 113
# 256 ==like=>> 36
# 256 ==like=>> 124
# 256 ==like=>> 102
# 256 ==like=>> 157
# 256 ==like=>> 179
# 256 ==like=>> 201
# 256 ==like=>> 14
# 256 ==like=>> 168
# 256 ==like=>> 69
# 256 ==like=>> 135
# 256 ==like=>> 344
# 256 ==like=>> 80
# 256 ==like=>> 421
# 256 ==like=>> 58
# 257 /1000
# 257 ==like=>> 59
# 257 ==like=>> 323
# 257 ==like=>> 312
# 257 ==like=>> 125
# 257 ==like=>> 147
# 258 /1000
# 259 /1000
# 260 /1000
# 260 ==like=>> 313
# 261 /1000
# 261 ==like=>> 447
# 261 ==like=>> 303
# 261 ==like=>> 96
# 261 ==like=>> 360
# 261 ==like=>> 371
# 261 ==like=>> 382
# 262 /1000
# 262 ==like=>> 427
# 262 ==like=>> 361
# 262 ==like=>> 9
# 263 /1000
# 264 /1000
# 265 /1000
# 265 ==like=>> 276
# 265 ==like=>> 144
# 265 ==like=>> 78
# 265 ==like=>> 133
# 266 /1000
# 266 ==like=>> 132
# 266 ==like=>> 189
# 266 ==like=>> 123
# 266 ==like=>> 442
# 266 ==like=>> 233
# 267 /1000
# 267 ==like=>> 355
# 267 ==like=>> 302
# 267 ==like=>> 25
# 267 ==like=>> 322
# 267 ==like=>> 344
# 267 ==like=>> 333
# 267 ==like=>> 212
# 267 ==like=>> 190
# 267 ==like=>> 421
# 268 /1000
# 268 ==like=>> 444
# 268 ==like=>> 301
# 268 ==like=>> 81
# 268 ==like=>> 246
# 268 ==like=>> 433
# 268 ==like=>> 158
# 268 ==like=>> 312
# 268 ==like=>> 92
# 268 ==like=>> 191
# 268 ==like=>> 290
# 268 ==like=>> 147
# 268 ==like=>> 367
# 268 ==like=>> 378
# 268 ==like=>> 224
# 269 /1000
# 269 ==like=>> 185
# 269 ==like=>> 302
# 269 ==like=>> 118
# 269 ==like=>> 89
# 270 /1000
# 271 /1000
# 272 /1000
# 272 ==like=>> 162
# 272 ==like=>> 447
# 272 ==like=>> 96
# 272 ==like=>> 371
# 272 ==like=>> 382
# 273 /1000
# 273 ==like=>> 152
# 273 ==like=>> 141
# 273 ==like=>> 361
# 273 ==like=>> 64
# 274 /1000
# 274 ==like=>> 55
# 275 /1000
# 276 /1000
# 277 /1000
# 278 /1000
# 278 ==like=>> 322
# 278 ==like=>> 212
# 278 ==like=>> 14
# 278 ==like=>> 80
# 278 ==like=>> 3
# 278 ==like=>> 421
# 278 ==like=>> 399
# 278 ==like=>> 333
# 278 ==like=>> 366
# 278 ==like=>> 377
# 278 ==like=>> 102
# 279 /1000
# 279 ==like=>> 444
# 279 ==like=>> 312
# 279 ==like=>> 158
# 279 ==like=>> 136
# 279 ==like=>> 70
# 279 ==like=>> 246
# 280 /1000
# 281 /1000
# 282 /1000
# 283 /1000
# 283 ==like=>> 263
# 283 ==like=>> 299
# 283 ==like=>> 303
# 283 ==like=>> 371
# 283 ==like=>> 382
# 283 ==like=>> 93
# 284 /1000
# 284 ==like=>> 64
# 284 ==like=>> 251
# 284 ==like=>> 361
# 284 ==like=>> 416
# 284 ==like=>> 350
# 284 ==like=>> 427
# 285 /1000
# 285 ==like=>> 55
# 286 /1000
# 286 ==like=>> 145
# 286 ==like=>> 220
# 287 /1000
# 287 ==like=>> 302
# 287 ==like=>> 313
# 287 ==like=>> 100
# 287 ==like=>> 320
# 287 ==like=>> 89
# 287 ==like=>> 23
# 287 ==like=>> 53
# 288 /1000
# 289 /1000
# 289 ==like=>> 25
# 290 /1000
# 290 ==like=>> 432
# 290 ==like=>> 389
# 290 ==like=>> 191
# 290 ==like=>> 81
# 290 ==like=>> 301
# 290 ==like=>> 345
# 290 ==like=>> 213
# 290 ==like=>> 103
# 290 ==like=>> 70
# 290 ==like=>> 433
# 290 ==like=>> 202
# 290 ==like=>> 37
# 290 ==like=>> 147
# 290 ==like=>> 246
# 290 ==like=>> 14
# 290 ==like=>> 180
# 290 ==like=>> 35
# 290 ==like=>> 367
# 290 ==like=>> 378
# 291 /1000
# 292 /1000
# 292 ==like=>> 49
# 292 ==like=>> 446
# 292 ==like=>> 203
# 292 ==like=>> 302
# 292 ==like=>> 173
# 292 ==like=>> 299
# 292 ==like=>> 294
# 292 ==like=>> 197
# 292 ==like=>> 89
# 293 /1000
# 293 ==like=>> 302
# 294 /1000
# 294 ==like=>> 327
# 294 ==like=>> 203
# 295 /1000
# 296 /1000
# 297 /1000
# 297 ==like=>> 258
# 298 /1000
# 298 ==like=>> 82
# 298 ==like=>> 148
# 299 /1000
# 300 /1000
# 301 /1000
# 301 ==like=>> 26
# 301 ==like=>> 48
# 301 ==like=>> 268
# 301 ==like=>> 81
# 301 ==like=>> 389
# 301 ==like=>> 103
# 301 ==like=>> 246
# 301 ==like=>> 213
# 301 ==like=>> 92
# 301 ==like=>> 290
# 301 ==like=>> 59
# 301 ==like=>> 235
# 301 ==like=>> 147
# 301 ==like=>> 312
# 301 ==like=>> 169
# 301 ==like=>> 114
# 301 ==like=>> 367
# 301 ==like=>> 378
# 302 /1000
# 302 ==like=>> 385
# 302 ==like=>> 247
# 303 /1000
# 303 ==like=>> 116
# 304 /1000
# 305 /1000
# 306 /1000
# 306 ==like=>> 328
# 306 ==like=>> 75
# 306 ==like=>> 350
# 306 ==like=>> 361
# 307 /1000
# 307 ==like=>> 263
# 307 ==like=>> 203
# 307 ==like=>> 302
# 307 ==like=>> 424
# 307 ==like=>> 55
# 307 ==like=>> 49
# 307 ==like=>> 446
# 307 ==like=>> 173
# 308 /1000
# 309 /1000
# 309 ==like=>> 423
# 309 ==like=>> 56
# 309 ==like=>> 263
# 310 /1000
# 310 ==like=>> 321
# 311 /1000
# 311 ==like=>> 411
# 311 ==like=>> 4
# 311 ==like=>> 147
# 311 ==like=>> 14
# 311 ==like=>> 80
# 311 ==like=>> 344
# 311 ==like=>> 170
# 311 ==like=>> 124
# 311 ==like=>> 245
# 312 /1000
# 312 ==like=>> 323
# 312 ==like=>> 37
# 312 ==like=>> 389
# 312 ==like=>> 279
# 312 ==like=>> 301
# 312 ==like=>> 290
# 312 ==like=>> 191
# 312 ==like=>> 345
# 312 ==like=>> 125
# 312 ==like=>> 169
# 312 ==like=>> 246
# 312 ==like=>> 147
# 312 ==like=>> 367
# 312 ==like=>> 378
# 312 ==like=>> 257
# 312 ==like=>> 235
# 312 ==like=>> 92
# 312 ==like=>> 213
# 312 ==like=>> 59
# 312 ==like=>> 268
# 313 /1000
# 313 ==like=>> 385
# 314 /1000
# 314 ==like=>> 38
# 314 ==like=>> 203
# 314 ==like=>> 82
# 314 ==like=>> 33
# 315 /1000
# 315 ==like=>> 414
# 316 /1000
# 316 ==like=>> 116
# 316 ==like=>> 83
# 316 ==like=>> 203
# 317 /1000
# 317 ==like=>> 64
# 317 ==like=>> 174
# 318 /1000
# 319 /1000
# 319 ==like=>> 330
# 320 /1000
# 320 ==like=>> 23
# 321 /1000
# 321 ==like=>> 221
# 322 /1000
# 322 ==like=>> 147
# 322 ==like=>> 278
# 322 ==like=>> 267
# 322 ==like=>> 14
# 322 ==like=>> 113
# 322 ==like=>> 124
# 322 ==like=>> 80
# 322 ==like=>> 344
# 322 ==like=>> 212
# 322 ==like=>> 245
# 322 ==like=>> 58
# 322 ==like=>> 366
# 322 ==like=>> 377
# 322 ==like=>> 179
# 322 ==like=>> 201
# 322 ==like=>> 333
# 322 ==like=>> 234
# 322 ==like=>> 256
# 322 ==like=>> 157
# 322 ==like=>> 190
# 322 ==like=>> 168
# 323 /1000
# 323 ==like=>> 312
# 323 ==like=>> 257
# 323 ==like=>> 125
# 323 ==like=>> 422
# 324 /1000
# 325 /1000
# 325 ==like=>> 307
# 326 /1000
# 326 ==like=>> 253
# 326 ==like=>> 247
# 326 ==like=>> 307
# 327 /1000
# 327 ==like=>> 294
# 327 ==like=>> 88
# 327 ==like=>> 299
# 327 ==like=>> 56
# 327 ==like=>> 316
# 328 /1000
# 328 ==like=>> 306
# 328 ==like=>> 42
# 329 /1000
# 330 /1000
# 331 /1000
# 332 /1000
# 332 ==like=>> 287
# 333 /1000
# 333 ==like=>> 411
# 333 ==like=>> 302
# 333 ==like=>> 267
# 333 ==like=>> 14
# 333 ==like=>> 113
# 333 ==like=>> 212
# 333 ==like=>> 124
# 333 ==like=>> 80
# 333 ==like=>> 388
# 333 ==like=>> 157
# 333 ==like=>> 344
# 333 ==like=>> 58
# 333 ==like=>> 223
# 333 ==like=>> 179
# 333 ==like=>> 201
# 333 ==like=>> 256
# 333 ==like=>> 410
# 333 ==like=>> 322
# 334 /1000
# 334 ==like=>> 103
# 334 ==like=>> 355
# 334 ==like=>> 385
# 334 ==like=>> 432
# 334 ==like=>> 168
# 335 /1000
# 336 /1000
# 336 ==like=>> 303
# 336 ==like=>> 171
# 336 ==like=>> 299
# 336 ==like=>> 349
# 336 ==like=>> 397
# 337 /1000
# 337 ==like=>> 313
# 338 /1000
# 338 ==like=>> 349
# 338 ==like=>> 397
# 338 ==like=>> 118
# 338 ==like=>> 140
# 339 /1000
# 339 ==like=>> 31
# 339 ==like=>> 251
# 340 /1000
# 341 /1000
# 341 ==like=>> 253
# 341 ==like=>> 187
# 342 /1000
# 343 /1000
# 343 ==like=>> 13
# 343 ==like=>> 442
# 344 /1000
# 344 ==like=>> 91
# 344 ==like=>> 168
# 344 ==like=>> 80
# 344 ==like=>> 157
# 344 ==like=>> 47
# 344 ==like=>> 267
# 344 ==like=>> 201
# 344 ==like=>> 322
# 344 ==like=>> 124
# 344 ==like=>> 102
# 344 ==like=>> 58
# 344 ==like=>> 256
# 344 ==like=>> 212
# 344 ==like=>> 311
# 344 ==like=>> 355
# 344 ==like=>> 113
# 344 ==like=>> 333
# 344 ==like=>> 399
# 344 ==like=>> 421
# 345 /1000
# 345 ==like=>> 4
# 345 ==like=>> 15
# 345 ==like=>> 312
# 345 ==like=>> 290
# 345 ==like=>> 59
# 345 ==like=>> 367
# 345 ==like=>> 378
# 345 ==like=>> 235
# 345 ==like=>> 410
# 345 ==like=>> 47
# 345 ==like=>> 147
# 345 ==like=>> 169
# 345 ==like=>> 114
# 346 /1000
# 347 /1000
# 347 ==like=>> 423
# 347 ==like=>> 358
# 347 ==like=>> 386
# 347 ==like=>> 364
# 347 ==like=>> 375
# 348 /1000
# 349 /1000
# 349 ==like=>> 314
# 349 ==like=>> 33
# 349 ==like=>> 250
# 349 ==like=>> 307
# 349 ==like=>> 85
# 349 ==like=>> 393
# 349 ==like=>> 22
# 349 ==like=>> 66
# 349 ==like=>> 88
# 350 /1000
# 350 ==like=>> 306
# 350 ==like=>> 328
# 350 ==like=>> 229
# 350 ==like=>> 130
# 350 ==like=>> 240
# 350 ==like=>> 218
# 351 /1000
# 351 ==like=>> 109
# 351 ==like=>> 55
# 351 ==like=>> 162
# 351 ==like=>> 49
# 351 ==like=>> 446
# 351 ==like=>> 291
# 351 ==like=>> 417
# 351 ==like=>> 22
# 351 ==like=>> 56
# 352 /1000
# 353 /1000
# 353 ==like=>> 313
# 353 ==like=>> 423
# 353 ==like=>> 25
# 353 ==like=>> 247
# 353 ==like=>> 56
# 354 /1000
# 355 /1000
# 356 /1000
# 356 ==like=>> 147
# 356 ==like=>> 114
# 357 /1000
# 357 ==like=>> 173
# 358 /1000
# 359 /1000
# 359 ==like=>> 16
# 359 ==like=>> 185
# 360 /1000
# 360 ==like=>> 74
# 360 ==like=>> 89
# 360 ==like=>> 96
# 360 ==like=>> 261
# 360 ==like=>> 283
# 360 ==like=>> 118
# 361 /1000
# 361 ==like=>> 64
# 362 /1000
# 363 /1000
# 364 /1000
# 364 ==like=>> 302
# 364 ==like=>> 423
# 364 ==like=>> 386
# 364 ==like=>> 281
# 364 ==like=>> 185
# 365 /1000
# 366 /1000
# 366 ==like=>> 80
# 366 ==like=>> 58
# 366 ==like=>> 3
# 366 ==like=>> 245
# 366 ==like=>> 212
# 366 ==like=>> 399
# 366 ==like=>> 322
# 366 ==like=>> 234
# 366 ==like=>> 333
# 367 /1000
# 367 ==like=>> 103
# 367 ==like=>> 48
# 367 ==like=>> 410
# 367 ==like=>> 389
# 367 ==like=>> 191
# 367 ==like=>> 301
# 367 ==like=>> 59
# 367 ==like=>> 312
# 367 ==like=>> 268
# 367 ==like=>> 355
# 367 ==like=>> 246
# 367 ==like=>> 168
# 367 ==like=>> 213
# 367 ==like=>> 202
# 367 ==like=>> 224
# 368 /1000
# 369 /1000
# 369 ==like=>> 72
# 370 /1000
# 370 ==like=>> 349
# 370 ==like=>> 397
# 370 ==like=>> 253
# 371 /1000
# 371 ==like=>> 96
# 372 /1000
# 372 ==like=>> 17
# 372 ==like=>> 302
# 372 ==like=>> 340
# 372 ==like=>> 427
# 372 ==like=>> 306
# 372 ==like=>> 229
# 372 ==like=>> 64
# 373 /1000
# 374 /1000
# 375 /1000
# 375 ==like=>> 302
# 375 ==like=>> 423
# 375 ==like=>> 386
# 375 ==like=>> 281
# 375 ==like=>> 185
# 376 /1000
# 377 /1000
# 377 ==like=>> 80
# 377 ==like=>> 58
# 377 ==like=>> 3
# 377 ==like=>> 245
# 377 ==like=>> 212
# 377 ==like=>> 399
# 377 ==like=>> 322
# 377 ==like=>> 234
# 377 ==like=>> 333
# 378 /1000
# 378 ==like=>> 103
# 378 ==like=>> 48
# 378 ==like=>> 410
# 378 ==like=>> 389
# 378 ==like=>> 191
# 378 ==like=>> 301
# 378 ==like=>> 59
# 378 ==like=>> 312
# 378 ==like=>> 268
# 378 ==like=>> 355
# 378 ==like=>> 246
# 378 ==like=>> 168
# 378 ==like=>> 213
# 378 ==like=>> 202
# 378 ==like=>> 224
# 379 /1000
# 380 /1000
# 380 ==like=>> 72
# 381 /1000
# 381 ==like=>> 349
# 381 ==like=>> 397
# 381 ==like=>> 253
# 382 /1000
# 382 ==like=>> 96
# 383 /1000
# 383 ==like=>> 17
# 383 ==like=>> 302
# 383 ==like=>> 340
# 383 ==like=>> 427
# 383 ==like=>> 306
# 383 ==like=>> 229
# 383 ==like=>> 64
# 384 /1000
# 384 ==like=>> 55
# 385 /1000
# 385 ==like=>> 313
# 386 /1000
# 387 /1000
# 387 ==like=>> 354
# 388 /1000
# 388 ==like=>> 103
# 388 ==like=>> 333
# 388 ==like=>> 47
# 388 ==like=>> 421
# 388 ==like=>> 157
# 388 ==like=>> 36
# 388 ==like=>> 399
# 388 ==like=>> 168
# 388 ==like=>> 91
# 388 ==like=>> 355
# 388 ==like=>> 432
# 388 ==like=>> 322
# 388 ==like=>> 69
# 389 /1000
# 389 ==like=>> 444
# 389 ==like=>> 70
# 389 ==like=>> 114
# 389 ==like=>> 37
# 389 ==like=>> 81
# 389 ==like=>> 48
# 390 /1000
# 391 /1000
# 391 ==like=>> 302
# 391 ==like=>> 448
# 392 /1000
# 393 /1000
# 393 ==like=>> 413
# 393 ==like=>> 283
# 393 ==like=>> 118
# 393 ==like=>> 349
# 393 ==like=>> 397
# 393 ==like=>> 162
# 393 ==like=>> 8
# 393 ==like=>> 314
# 394 /1000
# 394 ==like=>> 438
# 394 ==like=>> 196
# 394 ==like=>> 251
# 394 ==like=>> 416
# 395 /1000
# 395 ==like=>> 206
# 396 /1000
# 396 ==like=>> 302
# 396 ==like=>> 385
# 397 /1000
# 397 ==like=>> 314
# 397 ==like=>> 33
# 397 ==like=>> 250
# 397 ==like=>> 307
# 397 ==like=>> 85
# 397 ==like=>> 393
# 397 ==like=>> 22
# 397 ==like=>> 66
# 397 ==like=>> 88
# 398 /1000
# 398 ==like=>> 324
# 399 /1000
# 399 ==like=>> 113
# 399 ==like=>> 168
# 399 ==like=>> 91
# 399 ==like=>> 80
# 399 ==like=>> 256
# 399 ==like=>> 234
# 399 ==like=>> 201
# 399 ==like=>> 212
# 399 ==like=>> 124
# 399 ==like=>> 311
# 399 ==like=>> 179
# 399 ==like=>> 333
# 399 ==like=>> 47
# 399 ==like=>> 421
# 399 ==like=>> 69
# 400 /1000
# 400 ==like=>> 302
# 400 ==like=>> 444
# 400 ==like=>> 367
# 400 ==like=>> 378
# 400 ==like=>> 92
# 400 ==like=>> 169
# 400 ==like=>> 433
# 400 ==like=>> 213
# 400 ==like=>> 136
# 400 ==like=>> 389
# 400 ==like=>> 191
# 400 ==like=>> 81
# 400 ==like=>> 37
# 400 ==like=>> 48
# 400 ==like=>> 202
# 400 ==like=>> 235
# 400 ==like=>> 312
# 400 ==like=>> 290
# 400 ==like=>> 246
# 400 ==like=>> 268
# 401 /1000
# 401 ==like=>> 82
# 401 ==like=>> 93
# 401 ==like=>> 362
# 401 ==like=>> 373
# 402 /1000
# 403 /1000
# 404 /1000
# 405 /1000
# 405 ==like=>> 416
# 406 /1000
# 406 ==like=>> 55
# 406 ==like=>> 3
# 407 /1000
# 407 ==like=>> 302
# 407 ==like=>> 82
# 407 ==like=>> 237
# 407 ==like=>> 109
# 407 ==like=>> 423
# 407 ==like=>> 252
# 407 ==like=>> 162
# 408 /1000
# 408 ==like=>> 237
# 408 ==like=>> 186
# 408 ==like=>> 263
# 408 ==like=>> 294
# 409 /1000
# 410 /1000
# 410 ==like=>> 367
# 410 ==like=>> 378
# 410 ==like=>> 202
# 410 ==like=>> 48
# 410 ==like=>> 345
# 410 ==like=>> 245
# 410 ==like=>> 147
# 411 /1000
# 411 ==like=>> 432
# 411 ==like=>> 311
# 411 ==like=>> 124
# 411 ==like=>> 168
# 411 ==like=>> 179
# 411 ==like=>> 399
# 411 ==like=>> 47
# 411 ==like=>> 201
# 412 /1000
# 412 ==like=>> 89
# 413 /1000
# 414 /1000
# 414 ==like=>> 39
# 415 /1000
# 415 ==like=>> 0
# 415 ==like=>> 294
# 415 ==like=>> 22
# 415 ==like=>> 307
# 415 ==like=>> 393
# 415 ==like=>> 33
# 415 ==like=>> 77
# 415 ==like=>> 304
# 415 ==like=>> 292
# 416 /1000
# 417 /1000
# 417 ==like=>> 302
# 417 ==like=>> 55
# 417 ==like=>> 10
# 417 ==like=>> 30
# 417 ==like=>> 66
# 417 ==like=>> 0
# 418 /1000
# 419 /1000
# 420 /1000
# 420 ==like=>> 398
# 421 /1000
# 421 ==like=>> 147
# 421 ==like=>> 14
# 421 ==like=>> 201
# 421 ==like=>> 80
# 421 ==like=>> 157
# 421 ==like=>> 58
# 421 ==like=>> 278
# 421 ==like=>> 234
# 422 /1000
# 422 ==like=>> 323
# 422 ==like=>> 246
# 422 ==like=>> 334
# 423 /1000
# 423 ==like=>> 10
# 423 ==like=>> 353
# 424 /1000
# 424 ==like=>> 203
# 424 ==like=>> 307
# 424 ==like=>> 291
# 424 ==like=>> 88
# 425 /1000
# 425 ==like=>> 83
# 425 ==like=>> 261
# 425 ==like=>> 307
# 426 /1000
# 427 /1000
# 428 /1000
# 428 ==like=>> 280
# 428 ==like=>> 82
# 428 ==like=>> 162
# 428 ==like=>> 424
# 428 ==like=>> 299
# 428 ==like=>> 55
# 428 ==like=>> 33
# 429 /1000
# 430 /1000
# 430 ==like=>> 302
# 431 /1000
# 431 ==like=>> 398
# 432 /1000
# 432 ==like=>> 411
# 432 ==like=>> 103
# 432 ==like=>> 4
# 432 ==like=>> 334
# 432 ==like=>> 146
# 432 ==like=>> 234
# 432 ==like=>> 388
# 433 /1000
# 433 ==like=>> 345
# 433 ==like=>> 389
# 433 ==like=>> 268
# 433 ==like=>> 213
# 433 ==like=>> 312
# 433 ==like=>> 202
# 433 ==like=>> 147
# 433 ==like=>> 334
# 434 /1000
# 434 ==like=>> 313
# 435 /1000
# 436 /1000
# 437 /1000
# 438 /1000
# 438 ==like=>> 2
# 439 /1000
# 439 ==like=>> 302
# 439 ==like=>> 33
# 439 ==like=>> 55
# 440 /1000
# 440 ==like=>> 302
# 440 ==like=>> 132
# 441 /1000
# 442 /1000
# 443 /1000
# 444 /1000
# 444 ==like=>> 279
# 444 ==like=>> 313
# 444 ==like=>> 432
# 444 ==like=>> 15
# 444 ==like=>> 301
# 444 ==like=>> 367
# 444 ==like=>> 378
# 444 ==like=>> 81
# 444 ==like=>> 158
# 444 ==like=>> 92
# 444 ==like=>> 168
# 444 ==like=>> 257
# 444 ==like=>> 37
# 444 ==like=>> 290
# 444 ==like=>> 103
# 444 ==like=>> 70
# 444 ==like=>> 59
# 444 ==like=>> 246
# 444 ==like=>> 147
# 444 ==like=>> 224
# 444 ==like=>> 191
# 445 /1000
# 445 ==like=>> 263
# 446 /1000
# 446 ==like=>> 241
# 446 ==like=>> 362
# 446 ==like=>> 373
# 446 ==like=>> 307
# 446 ==like=>> 0
# 446 ==like=>> 294
# 446 ==like=>> 162
# 446 ==like=>> 88
# 446 ==like=>> 33
# 446 ==like=>> 173
# 446 ==like=>> 22
# 446 ==like=>> 316
# 447 /1000
# 448 /1000
# 448 ==like=>> 149
# 448 ==like=>> 423
# 448 ==like=>> 89
# 448 ==like=>> 391
# 448 ==like=>> 206
# 448 ==like=>> 16
# 448 ==like=>> 299
# 448 ==like=>> 371
# 448 ==like=>> 382

# %%
pd.DataFrame(list_edge).to_csv("A_nw_25day.csv")

# %%
len(list_edge)
# Out:
# 858

# %%
dd=pd.read_csv("A_nw_25day.csv").drop("Unnamed: 0",axis=1)
dd.head()
# Out:
#    0    1
# 0  0  109
# 1  0  252
# 2  0  417
# 3  0   49
# 4  0  446

# %%
dd.shape
# Out:
# (858, 2)
