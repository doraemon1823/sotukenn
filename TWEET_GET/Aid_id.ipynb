# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys,os

df=pd.read_csv("B-id_friends.csv")
df=df[1:]
df=df.drop("Unnamed: 0",axis=1)
df=df.reset_index()
df=df.drop("index",axis=1)
list_a = list(range(201))
df.columns=list_a

# %%
df[0].to_csv("B-id_friends!_id_list.csv")
# Out:
# /home/deeps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
d
# Out:
#                      0             1             2             3    \
# 0     980453684206215169  1.220020e+18  1.168278e+18  9.734919e+17
# 1    1135126281186451456  4.796841e+09  1.219101e+18  1.103625e+18
# 2              101784326  1.218068e+18  1.088319e+09  1.173468e+18
# 3              207158734  1.210420e+18  2.941584e+09  5.423893e+08
# 4              192487421  1.384098e+08  1.054672e+18  3.277933e+09
# 5     976283119727751169  1.210793e+18  1.349288e+09  1.101994e+18
# 6    1001999522703147008  1.036207e+18  7.722743e+17  1.144745e+18
# 7             2549710616  9.665483e+17  3.340188e+08  1.112551e+18
# 8     975373414314557440  7.150886e+17  2.619525e+08  1.202192e+18
# 9    1193815981988036608  2.170241e+09  1.209010e+18  1.118164e+18
# 10            3255348722  9.648065e+17  1.149365e+18  1.215997e+18
# 11   1001478220150009857  1.100487e+18  1.220325e+18  2.881976e+09
# 12   1176487672593825792  2.372361e+08  9.077936e+17  4.853731e+07
# ...

# %%
ID=df[0]
id_num=0
list_edge=[]
print("START !!!!")
for loc_num in range(449):
    #loc_num=500+loc_num
    print(loc_num,"/1000")
    for next_num in range(200):
        for id_num in range(449):
            if df.loc[loc_num][next_num+1]==ID[id_num]:
                print(loc_num,"==like=>>",id_num)
                case=([loc_num,id_num])
                list_edge.append(case)
            else:
                pass
# Out:
# START !!!!
# 0 /1000
# 0 ==like=>> 109
# 0 ==like=>> 252
# 0 ==like=>> 417
# 0 ==like=>> 49
# 0 ==like=>> 446
# 0 ==like=>> 318
# 0 ==like=>> 41
# 0 ==like=>> 162
# 0 ==like=>> 22
# 0 ==like=>> 241
# 0 ==like=>> 316
# 0 ==like=>> 217
# 1 /1000
# 1 ==like=>> 78
# 1 ==like=>> 265
# 1 ==like=>> 25
# 2 /1000
# 2 ==like=>> 442
# 2 ==like=>> 321
# 3 /1000
# 3 ==like=>> 355
# 3 ==like=>> 147
# 4 /1000
# 4 ==like=>> 202
# 4 ==like=>> 169
# 4 ==like=>> 114
# 5 /1000
# 5 ==like=>> 71
# 5 ==like=>> 173
# 6 /1000
# 6 ==like=>> 118
# 6 ==like=>> 313
# 6 ==like=>> 423
# 6 ==like=>> 303
# 7 /1000
# 7 ==like=>> 302
# 7 ==like=>> 258
# 7 ==like=>> 324
# 8 /1000
# 8 ==like=>> 41
# 8 ==like=>> 115
# 8 ==like=>> 407
# 8 ==like=>> 349
# 8 ==like=>> 397
# 9 /1000
# 9 ==like=>> 97
# 9 ==like=>> 262
# 9 ==like=>> 31
# 9 ==like=>> 438
# 9 ==like=>> 108
# 9 ==like=>> 141
# 10 /1000
# 10 ==like=>> 162
# 10 ==like=>> 109
# 10 ==like=>> 22
# 10 ==like=>> 115
# 10 ==like=>> 423
# 10 ==like=>> 173
# ...

# %%
pd.DataFrame(list_edge).to_csv("A_nw_25day.csv")

# %%
len(list_edge)
# Out:
# 858

# %%
dd=pd.read_csv("A_nw_25day.csv").drop("Unnamed: 0",axis=1)
dd.head()
# Out:
#    0    1
# 0  0  109
# 1  0  252
# 2  0  417
# 3  0   49
# 4  0  446

# %%
dd.shape
# Out:
# (858, 2)
