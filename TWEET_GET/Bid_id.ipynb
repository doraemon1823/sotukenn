# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys,os

df=pd.read_csv("Aid_Friends.csv")
df=df[1:]
df=df.drop("Unnamed: 0",axis=1)
df=df.reset_index()
df=df.drop("index",axis=1)
list_a = list(range(201))
df.columns=list_a

# %%
df[0].to_csv("Aid_Friends!_id_list.csv")
# Out:
# /home/deeps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
ID=df[0]
id_num=0
list_edge=[]
print("START !!!!")
for loc_num in range(449):
    #loc_num=500+loc_num
    print(loc_num,"/1000")
    for next_num in range(200):
        for id_num in range(449):
            if df.loc[loc_num][next_num+1]==ID[id_num]:
                print(loc_num,"==like=>>",id_num)
                case=([loc_num,id_num])
                list_edge.append(case)
            else:
                pass
# Out:
# START !!!!
# 0 /1000
# 0 ==like=>> 11
# 0 ==like=>> 33
# 0 ==like=>> 44
# 0 ==like=>> 55
# 0 ==like=>> 66
# 0 ==like=>> 77
# 0 ==like=>> 88
# 0 ==like=>> 99
# 0 ==like=>> 110
# 0 ==like=>> 121
# 0 ==like=>> 143
# 0 ==like=>> 154
# 0 ==like=>> 165
# 0 ==like=>> 176
# 0 ==like=>> 187
# 0 ==like=>> 198
# 0 ==like=>> 209
# 0 ==like=>> 220
# 0 ==like=>> 231
# 0 ==like=>> 253
# 0 ==like=>> 264
# 0 ==like=>> 275
# 0 ==like=>> 286
# 0 ==like=>> 297
# 0 ==like=>> 319
# 0 ==like=>> 330
# 0 ==like=>> 341
# 0 ==like=>> 352
# 0 ==like=>> 363
# 0 ==like=>> 374
# 0 ==like=>> 385
# 0 ==like=>> 407
# 0 ==like=>> 418
# 0 ==like=>> 52
# 0 ==like=>> 440
# 0 ==like=>> 67
# 1 /1000
# 1 ==like=>> 23
# 1 ==like=>> 34
# 1 ==like=>> 45
# 1 ==like=>> 56
# 1 ==like=>> 67
# 1 ==like=>> 78
# 1 ==like=>> 89
# 1 ==like=>> 100
# 1 ==like=>> 111
# 1 ==like=>> 122
# 1 ==like=>> 133
# 1 ==like=>> 144
# 1 ==like=>> 155
# 1 ==like=>> 166
# 1 ==like=>> 177
# 1 ==like=>> 188
# 1 ==like=>> 199
# 1 ==like=>> 210
# 1 ==like=>> 221
# 1 ==like=>> 243
# 1 ==like=>> 254
# 1 ==like=>> 265
# 1 ==like=>> 276
# 1 ==like=>> 298
# 1 ==like=>> 309
# 1 ==like=>> 320
# 1 ==like=>> 342
# 1 ==like=>> 353
# 1 ==like=>> 364
# 1 ==like=>> 375
# 1 ==like=>> 386
# 1 ==like=>> 397
# 1 ==like=>> 408
# 1 ==like=>> 419
# 1 ==like=>> 430
# 1 ==like=>> 441
# 1 ==like=>> 38
# 2 /1000
# 2 ==like=>> 13
# 2 ==like=>> 35
# 2 ==like=>> 46
# 2 ==like=>> 68
# 2 ==like=>> 79
# 2 ==like=>> 90
# 2 ==like=>> 101
# 2 ==like=>> 112
# 2 ==like=>> 123
# 2 ==like=>> 145
# 2 ==like=>> 156
# 2 ==like=>> 167
# 2 ==like=>> 178
# 2 ==like=>> 189
# 2 ==like=>> 200
# 2 ==like=>> 211
# 2 ==like=>> 222
# 2 ==like=>> 233
# 2 ==like=>> 244
# 2 ==like=>> 255
# 2 ==like=>> 266
# 2 ==like=>> 277
# 2 ==like=>> 288
# 2 ==like=>> 310
# 2 ==like=>> 321
# 2 ==like=>> 332
# 2 ==like=>> 343
# 2 ==like=>> 354
# 2 ==like=>> 365
# 2 ==like=>> 376
# 2 ==like=>> 387
# 2 ==like=>> 398
# 2 ==like=>> 409
# 2 ==like=>> 420
# 2 ==like=>> 431
# 2 ==like=>> 442
# 2 ==like=>> 67
# 3 /1000
# 3 ==like=>> 14
# 3 ==like=>> 25
# 3 ==like=>> 36
# 3 ==like=>> 47
# 3 ==like=>> 58
# 3 ==like=>> 69
# 3 ==like=>> 80
# 3 ==like=>> 91
# 3 ==like=>> 102
# 3 ==like=>> 113
# 3 ==like=>> 124
# 3 ==like=>> 135
# 3 ==like=>> 146
# 3 ==like=>> 157
# 3 ==like=>> 168
# 3 ==like=>> 179
# 3 ==like=>> 190
# 3 ==like=>> 212
# 3 ==like=>> 223
# 3 ==like=>> 234
# 3 ==like=>> 245
# 3 ==like=>> 256
# 3 ==like=>> 267
# 3 ==like=>> 278
# 3 ==like=>> 289
# 3 ==like=>> 300
# 3 ==like=>> 311
# 3 ==like=>> 322
# 3 ==like=>> 333
# 3 ==like=>> 344
# 3 ==like=>> 355
# 3 ==like=>> 366
# 3 ==like=>> 377
# 3 ==like=>> 388
# 3 ==like=>> 399
# 3 ==like=>> 410
# 3 ==like=>> 421
# 3 ==like=>> 432
# 3 ==like=>> 443
# 4 /1000
# 4 ==like=>> 15
# 4 ==like=>> 26
# 4 ==like=>> 37
# 4 ==like=>> 59
# 4 ==like=>> 70
# 4 ==like=>> 81
# 4 ==like=>> 92
# 4 ==like=>> 114
# 4 ==like=>> 125
# 4 ==like=>> 136
# 4 ==like=>> 147
# 4 ==like=>> 180
# 4 ==like=>> 191
# 4 ==like=>> 202
# 4 ==like=>> 213
# 4 ==like=>> 224
# 4 ==like=>> 246
# 4 ==like=>> 257
# 4 ==like=>> 268
# 4 ==like=>> 279
# 4 ==like=>> 290
# 4 ==like=>> 301
# 4 ==like=>> 312
# 4 ==like=>> 323
# 4 ==like=>> 334
# 4 ==like=>> 345
# 4 ==like=>> 356
# 4 ==like=>> 367
# 4 ==like=>> 389
# 4 ==like=>> 400
# 4 ==like=>> 411
# 4 ==like=>> 422
# 4 ==like=>> 433
# 4 ==like=>> 444
# 5 /1000
# 5 ==like=>> 16
# 5 ==like=>> 27
# 5 ==like=>> 38
# 5 ==like=>> 49
# 5 ==like=>> 60
# 5 ==like=>> 71
# 5 ==like=>> 82
# 5 ==like=>> 93
# 5 ==like=>> 115
# 5 ==like=>> 126
# 5 ==like=>> 137
# 5 ==like=>> 159
# 5 ==like=>> 170
# 5 ==like=>> 192
# 5 ==like=>> 203
# 5 ==like=>> 214
# 5 ==like=>> 236
# 5 ==like=>> 247
# 5 ==like=>> 258
# 5 ==like=>> 269
# 5 ==like=>> 291
# 5 ==like=>> 302
# 5 ==like=>> 313
# 5 ==like=>> 324
# 5 ==like=>> 335
# 5 ==like=>> 346
# 5 ==like=>> 357
# 5 ==like=>> 368
# 5 ==like=>> 379
# 5 ==like=>> 10
# 5 ==like=>> 390
# 5 ==like=>> 401
# 5 ==like=>> 412
# 5 ==like=>> 423
# 5 ==like=>> 445
# 5 ==like=>> 59
# 5 ==like=>> 254
# 5 ==like=>> 343
# 5 ==like=>> 67
# 5 ==like=>> 61
# 5 ==like=>> 298
# 5 ==like=>> 39
# 5 ==like=>> 314
# 5 ==like=>> 382
# 5 ==like=>> 154
# 6 /1000
# 6 ==like=>> 17
# 6 ==like=>> 7
# 6 ==like=>> 28
# 6 ==like=>> 39
# 6 ==like=>> 50
# 6 ==like=>> 61
# 6 ==like=>> 8
# 6 ==like=>> 72
# 6 ==like=>> 94
# 6 ==like=>> 116
# 6 ==like=>> 127
# 6 ==like=>> 138
# 6 ==like=>> 149
# 6 ==like=>> 160
# 6 ==like=>> 171
# 6 ==like=>> 182
# 6 ==like=>> 204
# 6 ==like=>> 215
# 6 ==like=>> 226
# 6 ==like=>> 248
# 6 ==like=>> 270
# 6 ==like=>> 281
# 6 ==like=>> 292
# 6 ==like=>> 303
# 6 ==like=>> 314
# 6 ==like=>> 325
# 6 ==like=>> 9
# 6 ==like=>> 336
# 6 ==like=>> 347
# 6 ==like=>> 358
# 6 ==like=>> 369
# 6 ==like=>> 380
# 6 ==like=>> 391
# 6 ==like=>> 402
# 6 ==like=>> 413
# 6 ==like=>> 424
# 6 ==like=>> 446
# 6 ==like=>> 302
# 6 ==like=>> 59
# 6 ==like=>> 272
# 6 ==like=>> 151
# 7 /1000
# 7 ==like=>> 18
# 7 ==like=>> 29
# 7 ==like=>> 40
# 7 ==like=>> 51
# 7 ==like=>> 62
# 7 ==like=>> 73
# 7 ==like=>> 84
# 7 ==like=>> 95
# 7 ==like=>> 106
# 7 ==like=>> 164
# 7 ==like=>> 117
# 7 ==like=>> 128
# 7 ==like=>> 139
# 7 ==like=>> 150
# 7 ==like=>> 161
# 7 ==like=>> 172
# 7 ==like=>> 194
# 7 ==like=>> 205
# 7 ==like=>> 216
# 7 ==like=>> 227
# 7 ==like=>> 238
# 7 ==like=>> 249
# 7 ==like=>> 260
# 7 ==like=>> 271
# 7 ==like=>> 282
# 7 ==like=>> 293
# 7 ==like=>> 304
# 7 ==like=>> 315
# 7 ==like=>> 337
# 7 ==like=>> 348
# 7 ==like=>> 359
# 7 ==like=>> 381
# 7 ==like=>> 392
# 7 ==like=>> 403
# 7 ==like=>> 414
# 7 ==like=>> 425
# 7 ==like=>> 436
# 7 ==like=>> 447
# 7 ==like=>> 6
# 7 ==like=>> 19
# 7 ==like=>> 53
# 7 ==like=>> 219
# 7 ==like=>> 314
# 8 /1000
# 8 ==like=>> 6
# 8 ==like=>> 19
# 8 ==like=>> 53
# 8 ==like=>> 219
# 8 ==like=>> 30
# 8 ==like=>> 41
# 8 ==like=>> 52
# 8 ==like=>> 440
# 8 ==like=>> 63
# 8 ==like=>> 74
# 8 ==like=>> 85
# 8 ==like=>> 96
# 8 ==like=>> 107
# 8 ==like=>> 118
# 8 ==like=>> 129
# 8 ==like=>> 140
# 8 ==like=>> 151
# 8 ==like=>> 173
# 8 ==like=>> 184
# 8 ==like=>> 195
# 8 ==like=>> 206
# 8 ==like=>> 217
# 8 ==like=>> 228
# 8 ==like=>> 239
# 8 ==like=>> 250
# 8 ==like=>> 261
# 8 ==like=>> 272
# 8 ==like=>> 283
# 8 ==like=>> 294
# 8 ==like=>> 316
# 8 ==like=>> 349
# 8 ==like=>> 360
# 8 ==like=>> 371
# 8 ==like=>> 382
# 8 ==like=>> 393
# 8 ==like=>> 404
# 8 ==like=>> 415
# 8 ==like=>> 437
# 8 ==like=>> 448
# 8 ==like=>> 384
# 9 /1000
# 9 ==like=>> 20
# 9 ==like=>> 31
# 9 ==like=>> 42
# 9 ==like=>> 6
# 9 ==like=>> 19
# 9 ==like=>> 53
# 9 ==like=>> 219
# 9 ==like=>> 64
# 9 ==like=>> 75
# 9 ==like=>> 86
# 9 ==like=>> 97
# 9 ==like=>> 108
# 9 ==like=>> 130
# 9 ==like=>> 141
# 9 ==like=>> 152
# 9 ==like=>> 163
# 9 ==like=>> 174
# 9 ==like=>> 185
# 9 ==like=>> 196
# 9 ==like=>> 207
# 9 ==like=>> 218
# 9 ==like=>> 229
# 9 ==like=>> 240
# 9 ==like=>> 251
# 9 ==like=>> 262
# 9 ==like=>> 273
# 9 ==like=>> 295
# 9 ==like=>> 306
# 9 ==like=>> 317
# 9 ==like=>> 328
# 9 ==like=>> 339
# 9 ==like=>> 350
# 9 ==like=>> 361
# 9 ==like=>> 372
# 9 ==like=>> 394
# 9 ==like=>> 405
# 9 ==like=>> 416
# 9 ==like=>> 427
# 9 ==like=>> 438
# 10 /1000
# 11 /1000
# 12 /1000
# 12 ==like=>> 247
# 12 ==like=>> 1
# 12 ==like=>> 43
# 12 ==like=>> 352
# 12 ==like=>> 430
# 12 ==like=>> 199
# 12 ==like=>> 276
# 13 /1000
# 14 /1000
# 14 ==like=>> 59
# 14 ==like=>> 362
# 14 ==like=>> 245
# 14 ==like=>> 355
# 14 ==like=>> 179
# 14 ==like=>> 135
# 14 ==like=>> 3
# 14 ==like=>> 120
# 14 ==like=>> 334
# 14 ==like=>> 25
# 14 ==like=>> 322
# 14 ==like=>> 344
# 14 ==like=>> 333
# 14 ==like=>> 157
# 14 ==like=>> 113
# 15 /1000
# 15 ==like=>> 4
# 15 ==like=>> 131
# 15 ==like=>> 59
# 15 ==like=>> 268
# 15 ==like=>> 91
# 15 ==like=>> 334
# 15 ==like=>> 323
# 15 ==like=>> 344
# 15 ==like=>> 345
# 16 /1000
# 17 /1000
# 17 ==like=>> 18
# 17 ==like=>> 40
# 17 ==like=>> 62
# 17 ==like=>> 73
# 17 ==like=>> 84
# 17 ==like=>> 95
# 17 ==like=>> 106
# 17 ==like=>> 164
# 17 ==like=>> 117
# 17 ==like=>> 414
# 17 ==like=>> 447
# 17 ==like=>> 436
# 17 ==like=>> 6
# 17 ==like=>> 19
# 17 ==like=>> 53
# 17 ==like=>> 219
# 17 ==like=>> 314
# 18 /1000
# 19 /1000
# 19 ==like=>> 17
# 19 ==like=>> 7
# 19 ==like=>> 28
# 19 ==like=>> 39
# 19 ==like=>> 50
# 19 ==like=>> 61
# 19 ==like=>> 8
# 19 ==like=>> 72
# 19 ==like=>> 94
# 19 ==like=>> 116
# 19 ==like=>> 127
# 19 ==like=>> 138
# 19 ==like=>> 149
# 19 ==like=>> 160
# 19 ==like=>> 171
# 19 ==like=>> 182
# 19 ==like=>> 204
# 19 ==like=>> 215
# 19 ==like=>> 226
# 19 ==like=>> 248
# 19 ==like=>> 270
# 19 ==like=>> 281
# 19 ==like=>> 292
# 19 ==like=>> 303
# 19 ==like=>> 314
# 19 ==like=>> 325
# 19 ==like=>> 9
# 19 ==like=>> 336
# 19 ==like=>> 347
# 19 ==like=>> 358
# 19 ==like=>> 369
# 19 ==like=>> 380
# 19 ==like=>> 391
# 19 ==like=>> 402
# 19 ==like=>> 413
# 19 ==like=>> 424
# 19 ==like=>> 446
# 19 ==like=>> 302
# 19 ==like=>> 59
# 19 ==like=>> 272
# 19 ==like=>> 151
# 20 /1000
# 20 ==like=>> 167
# 20 ==like=>> 9
# 20 ==like=>> 336
# 20 ==like=>> 251
# 20 ==like=>> 416
# 21 /1000
# 22 /1000
# 22 ==like=>> 59
# 23 /1000
# 24 /1000
# 24 ==like=>> 35
# 25 /1000
# 25 ==like=>> 14
# 25 ==like=>> 422
# 25 ==like=>> 37
# 25 ==like=>> 278
# 26 /1000
# 26 ==like=>> 4
# 26 ==like=>> 131
# 26 ==like=>> 433
# 26 ==like=>> 422
# 27 /1000
# 28 /1000
# 28 ==like=>> 18
# 28 ==like=>> 29
# 28 ==like=>> 40
# 28 ==like=>> 51
# 28 ==like=>> 62
# 28 ==like=>> 73
# 28 ==like=>> 84
# 28 ==like=>> 95
# 28 ==like=>> 106
# 28 ==like=>> 164
# 28 ==like=>> 117
# 28 ==like=>> 128
# 28 ==like=>> 139
# 28 ==like=>> 150
# 28 ==like=>> 161
# 28 ==like=>> 172
# 28 ==like=>> 194
# 28 ==like=>> 205
# 28 ==like=>> 216
# 28 ==like=>> 227
# 28 ==like=>> 238
# 28 ==like=>> 249
# 28 ==like=>> 260
# 28 ==like=>> 271
# 28 ==like=>> 282
# 28 ==like=>> 293
# 28 ==like=>> 304
# 28 ==like=>> 315
# 28 ==like=>> 337
# 28 ==like=>> 348
# 28 ==like=>> 359
# 28 ==like=>> 392
# 28 ==like=>> 381
# 28 ==like=>> 403
# 28 ==like=>> 414
# 28 ==like=>> 425
# 28 ==like=>> 436
# 28 ==like=>> 447
# 28 ==like=>> 6
# 28 ==like=>> 19
# 28 ==like=>> 53
# 28 ==like=>> 219
# 28 ==like=>> 314
# 29 /1000
# 30 /1000
# 30 ==like=>> 8
# 30 ==like=>> 72
# 30 ==like=>> 380
# 30 ==like=>> 17
# 30 ==like=>> 151
# 30 ==like=>> 6
# 30 ==like=>> 19
# 30 ==like=>> 53
# 30 ==like=>> 219
# 30 ==like=>> 52
# 30 ==like=>> 440
# 30 ==like=>> 382
# 31 /1000
# 31 ==like=>> 185
# 31 ==like=>> 9
# 31 ==like=>> 336
# 31 ==like=>> 163
# 31 ==like=>> 240
# 31 ==like=>> 64
# 31 ==like=>> 416
# 31 ==like=>> 328
# 32 /1000
# 32 ==like=>> 11
# 32 ==like=>> 33
# 32 ==like=>> 44
# 32 ==like=>> 55
# 32 ==like=>> 66
# 32 ==like=>> 77
# 32 ==like=>> 88
# 32 ==like=>> 99
# 32 ==like=>> 110
# 32 ==like=>> 121
# 32 ==like=>> 143
# 32 ==like=>> 154
# 32 ==like=>> 165
# 32 ==like=>> 176
# 32 ==like=>> 187
# 32 ==like=>> 198
# 32 ==like=>> 209
# 32 ==like=>> 220
# 32 ==like=>> 231
# 32 ==like=>> 253
# 32 ==like=>> 264
# 32 ==like=>> 275
# 32 ==like=>> 286
# 32 ==like=>> 297
# 32 ==like=>> 319
# 32 ==like=>> 330
# 32 ==like=>> 341
# 32 ==like=>> 352
# 32 ==like=>> 363
# 32 ==like=>> 374
# 32 ==like=>> 385
# 32 ==like=>> 407
# 32 ==like=>> 418
# 32 ==like=>> 52
# 32 ==like=>> 440
# 32 ==like=>> 67
# 33 /1000
# 33 ==like=>> 89
# 34 /1000
# 34 ==like=>> 1
# 34 ==like=>> 43
# 34 ==like=>> 408
# 34 ==like=>> 122
# 34 ==like=>> 243
# 35 /1000
# 35 ==like=>> 59
# 36 /1000
# 37 /1000
# 37 ==like=>> 422
# 37 ==like=>> 4
# 37 ==like=>> 131
# 37 ==like=>> 102
# 37 ==like=>> 432
# 37 ==like=>> 278
# 37 ==like=>> 322
# 37 ==like=>> 344
# 37 ==like=>> 421
# 38 /1000
# 39 /1000
# 39 ==like=>> 6
# 39 ==like=>> 19
# 39 ==like=>> 53
# 39 ==like=>> 219
# 39 ==like=>> 45
# 39 ==like=>> 49
# 39 ==like=>> 153
# 39 ==like=>> 274
# 39 ==like=>> 382
# 40 /1000
# 41 /1000
# 41 ==like=>> 8
# 41 ==like=>> 72
# 41 ==like=>> 137
# 41 ==like=>> 382
# 41 ==like=>> 385
# 41 ==like=>> 391
# 42 /1000
# 42 ==like=>> 9
# 42 ==like=>> 336
# 43 /1000
# 43 ==like=>> 23
# 43 ==like=>> 34
# 43 ==like=>> 45
# 43 ==like=>> 56
# 43 ==like=>> 67
# 43 ==like=>> 78
# 43 ==like=>> 89
# 43 ==like=>> 100
# 43 ==like=>> 111
# 43 ==like=>> 122
# 43 ==like=>> 133
# 43 ==like=>> 144
# 43 ==like=>> 155
# 43 ==like=>> 166
# 43 ==like=>> 177
# 43 ==like=>> 188
# 43 ==like=>> 199
# 43 ==like=>> 210
# 43 ==like=>> 221
# 43 ==like=>> 243
# 43 ==like=>> 254
# 43 ==like=>> 265
# 43 ==like=>> 276
# 43 ==like=>> 298
# 43 ==like=>> 309
# 43 ==like=>> 320
# 43 ==like=>> 342
# 43 ==like=>> 353
# 43 ==like=>> 364
# 43 ==like=>> 375
# 43 ==like=>> 386
# 43 ==like=>> 397
# 43 ==like=>> 408
# 43 ==like=>> 419
# 43 ==like=>> 430
# 43 ==like=>> 441
# 43 ==like=>> 38
# 44 /1000
# 44 ==like=>> 384
# 44 ==like=>> 71
# 44 ==like=>> 206
# 44 ==like=>> 39
# 45 /1000
# 45 ==like=>> 137
# 45 ==like=>> 382
# 45 ==like=>> 1
# 45 ==like=>> 43
# 45 ==like=>> 49
# 45 ==like=>> 274
# 45 ==like=>> 52
# 45 ==like=>> 440
# 45 ==like=>> 236
# 46 /1000
# 47 /1000
# 48 /1000
# 49 /1000
# 49 ==like=>> 188
# 49 ==like=>> 10
# 49 ==like=>> 390
# 49 ==like=>> 382
# 49 ==like=>> 217
# 49 ==like=>> 272
# 49 ==like=>> 82
# 49 ==like=>> 39
# 49 ==like=>> 153
# 49 ==like=>> 439
# 50 /1000
# 51 /1000
# 52 /1000
# 52 ==like=>> 106
# 52 ==like=>> 164
# 52 ==like=>> 8
# 52 ==like=>> 72
# 52 ==like=>> 117
# 52 ==like=>> 39
# 52 ==like=>> 371
# 52 ==like=>> 6
# 52 ==like=>> 19
# 52 ==like=>> 53
# 52 ==like=>> 219
# 53 /1000
# 53 ==like=>> 17
# 53 ==like=>> 7
# 53 ==like=>> 28
# 53 ==like=>> 39
# 53 ==like=>> 50
# 53 ==like=>> 61
# 53 ==like=>> 8
# 53 ==like=>> 72
# 53 ==like=>> 94
# 53 ==like=>> 116
# 53 ==like=>> 127
# 53 ==like=>> 138
# 53 ==like=>> 149
# 53 ==like=>> 160
# 53 ==like=>> 171
# 53 ==like=>> 182
# 53 ==like=>> 204
# 53 ==like=>> 215
# 53 ==like=>> 226
# 53 ==like=>> 248
# 53 ==like=>> 270
# 53 ==like=>> 281
# 53 ==like=>> 292
# 53 ==like=>> 303
# 53 ==like=>> 314
# 53 ==like=>> 325
# 53 ==like=>> 9
# 53 ==like=>> 336
# 53 ==like=>> 347
# 53 ==like=>> 358
# 53 ==like=>> 369
# 53 ==like=>> 380
# 53 ==like=>> 391
# 53 ==like=>> 402
# 53 ==like=>> 413
# 53 ==like=>> 424
# 53 ==like=>> 446
# 53 ==like=>> 302
# 53 ==like=>> 59
# 53 ==like=>> 272
# 53 ==like=>> 151
# 54 /1000
# 54 ==like=>> 167
# 54 ==like=>> 67
# 55 /1000
# 56 /1000
# 57 /1000
# 57 ==like=>> 35
# 58 /1000
# 58 ==like=>> 59
# 58 ==like=>> 3
# 58 ==like=>> 120
# 59 /1000
# 60 /1000
# 61 /1000
# 61 ==like=>> 6
# 61 ==like=>> 19
# 61 ==like=>> 53
# 61 ==like=>> 219
# 62 /1000
# 63 /1000
# 63 ==like=>> 8
# 63 ==like=>> 72
# 63 ==like=>> 74
# 63 ==like=>> 71
# 64 /1000
# 64 ==like=>> 372
# 64 ==like=>> 9
# 64 ==like=>> 336
# 65 /1000
# 65 ==like=>> 13
# 65 ==like=>> 35
# 65 ==like=>> 46
# 65 ==like=>> 68
# 65 ==like=>> 79
# 65 ==like=>> 90
# 65 ==like=>> 101
# 65 ==like=>> 112
# 65 ==like=>> 123
# 65 ==like=>> 145
# 65 ==like=>> 156
# 65 ==like=>> 167
# 65 ==like=>> 178
# 65 ==like=>> 189
# 65 ==like=>> 200
# 65 ==like=>> 211
# 65 ==like=>> 222
# 65 ==like=>> 233
# 65 ==like=>> 244
# 65 ==like=>> 255
# 65 ==like=>> 266
# 65 ==like=>> 277
# 65 ==like=>> 288
# 65 ==like=>> 310
# 65 ==like=>> 321
# 65 ==like=>> 332
# 65 ==like=>> 343
# 65 ==like=>> 354
# 65 ==like=>> 365
# 65 ==like=>> 376
# 65 ==like=>> 387
# 65 ==like=>> 398
# 65 ==like=>> 409
# 65 ==like=>> 420
# 65 ==like=>> 431
# 65 ==like=>> 442
# 65 ==like=>> 67
# 66 /1000
# 66 ==like=>> 77
# 66 ==like=>> 59
# 67 /1000
# 67 ==like=>> 10
# 67 ==like=>> 390
# 67 ==like=>> 21
# 67 ==like=>> 0
# 67 ==like=>> 32
# 67 ==like=>> 1
# 67 ==like=>> 43
# 67 ==like=>> 54
# 67 ==like=>> 2
# 67 ==like=>> 65
# 67 ==like=>> 76
# 67 ==like=>> 87
# 67 ==like=>> 109
# 67 ==like=>> 3
# 67 ==like=>> 120
# 67 ==like=>> 4
# 67 ==like=>> 131
# 67 ==like=>> 142
# 67 ==like=>> 153
# 67 ==like=>> 106
# 67 ==like=>> 164
# 67 ==like=>> 175
# 67 ==like=>> 197
# 67 ==like=>> 6
# 67 ==like=>> 19
# 67 ==like=>> 53
# 67 ==like=>> 219
# 67 ==like=>> 241
# 67 ==like=>> 252
# 67 ==like=>> 274
# 67 ==like=>> 285
# 67 ==like=>> 296
# 67 ==like=>> 307
# 67 ==like=>> 318
# 67 ==like=>> 329
# 67 ==like=>> 351
# 67 ==like=>> 362
# 67 ==like=>> 373
# 67 ==like=>> 384
# 67 ==like=>> 395
# 67 ==like=>> 406
# 67 ==like=>> 417
# 67 ==like=>> 439
# 67 ==like=>> 61
# 67 ==like=>> 413
# 67 ==like=>> 234
# 68 /1000
# 68 ==like=>> 178
# 68 ==like=>> 244
# 69 /1000
# 69 ==like=>> 14
# 69 ==like=>> 102
# 69 ==like=>> 377
# 69 ==like=>> 135
# 69 ==like=>> 37
# 69 ==like=>> 59
# 69 ==like=>> 179
# 69 ==like=>> 25
# 69 ==like=>> 344
# 69 ==like=>> 334
# 69 ==like=>> 80
# 70 /1000
# 70 ==like=>> 444
# 70 ==like=>> 136
# 70 ==like=>> 4
# 70 ==like=>> 131
# 70 ==like=>> 345
# 71 /1000
# 71 ==like=>> 215
# 71 ==like=>> 17
# 71 ==like=>> 45
# 71 ==like=>> 30
# 72 /1000
# 72 ==like=>> 6
# 72 ==like=>> 19
# 72 ==like=>> 53
# 72 ==like=>> 219
# 72 ==like=>> 30
# 72 ==like=>> 41
# 72 ==like=>> 52
# 72 ==like=>> 440
# 72 ==like=>> 63
# 72 ==like=>> 74
# 72 ==like=>> 85
# 72 ==like=>> 96
# 72 ==like=>> 107
# 72 ==like=>> 118
# 72 ==like=>> 129
# 72 ==like=>> 140
# 72 ==like=>> 151
# 72 ==like=>> 173
# 72 ==like=>> 184
# 72 ==like=>> 195
# 72 ==like=>> 206
# 72 ==like=>> 217
# 72 ==like=>> 228
# 72 ==like=>> 239
# 72 ==like=>> 250
# 72 ==like=>> 261
# 72 ==like=>> 272
# 72 ==like=>> 283
# 72 ==like=>> 294
# 72 ==like=>> 316
# 72 ==like=>> 349
# 72 ==like=>> 360
# 72 ==like=>> 371
# 72 ==like=>> 382
# 72 ==like=>> 393
# 72 ==like=>> 404
# 72 ==like=>> 415
# 72 ==like=>> 437
# 72 ==like=>> 448
# 72 ==like=>> 384
# 73 /1000
# 74 /1000
# 75 /1000
# 75 ==like=>> 42
# 75 ==like=>> 9
# 75 ==like=>> 336
# 75 ==like=>> 152
# 75 ==like=>> 240
# 75 ==like=>> 416
# 76 /1000
# 76 ==like=>> 59
# 76 ==like=>> 52
# 76 ==like=>> 440
# 76 ==like=>> 407
# 76 ==like=>> 67
# 76 ==like=>> 270
# 76 ==like=>> 176
# 76 ==like=>> 187
# 77 /1000
# 77 ==like=>> 59
# 78 /1000
# 79 /1000
# 79 ==like=>> 387
# 80 /1000
# 80 ==like=>> 59
# 80 ==like=>> 135
# 80 ==like=>> 102
# 80 ==like=>> 113
# 80 ==like=>> 179
# 80 ==like=>> 69
# 80 ==like=>> 300
# 80 ==like=>> 322
# 80 ==like=>> 399
# 80 ==like=>> 355
# 80 ==like=>> 91
# 80 ==like=>> 289
# 80 ==like=>> 344
# 80 ==like=>> 278
# 80 ==like=>> 157
# 81 /1000
# 81 ==like=>> 345
# 81 ==like=>> 4
# 81 ==like=>> 131
# 81 ==like=>> 444
# 81 ==like=>> 114
# 81 ==like=>> 125
# 81 ==like=>> 257
# 81 ==like=>> 312
# 81 ==like=>> 400
# 81 ==like=>> 422
# 81 ==like=>> 246
# 82 /1000
# 83 /1000
# 83 ==like=>> 71
# 83 ==like=>> 382
# 83 ==like=>> 6
# 83 ==like=>> 19
# 83 ==like=>> 53
# 83 ==like=>> 219
# 84 /1000
# 85 /1000
# 85 ==like=>> 320
# 85 ==like=>> 8
# 85 ==like=>> 72
# 85 ==like=>> 195
# 85 ==like=>> 283
# 85 ==like=>> 382
# 85 ==like=>> 274
# 86 /1000
# 86 ==like=>> 174
# 86 ==like=>> 9
# 86 ==like=>> 336
# 86 ==like=>> 251
# 87 /1000
# 88 /1000
# 88 ==like=>> 0
# 88 ==like=>> 32
# 89 /1000
# 89 ==like=>> 274
# 89 ==like=>> 1
# 89 ==like=>> 43
# 89 ==like=>> 276
# 89 ==like=>> 254
# 89 ==like=>> 320
# 90 /1000
# 91 /1000
# 91 ==like=>> 14
# 91 ==like=>> 15
# 91 ==like=>> 323
# 91 ==like=>> 3
# 91 ==like=>> 120
# 91 ==like=>> 113
# 91 ==like=>> 278
# 91 ==like=>> 102
# 91 ==like=>> 179
# 91 ==like=>> 344
# 91 ==like=>> 135
# 91 ==like=>> 333
# 92 /1000
# 92 ==like=>> 4
# 92 ==like=>> 131
# 92 ==like=>> 422
# 93 /1000
# 94 /1000
# 94 ==like=>> 211
# 94 ==like=>> 254
# 95 /1000
# 96 /1000
# 96 ==like=>> 228
# 96 ==like=>> 206
# 96 ==like=>> 8
# 96 ==like=>> 72
# 96 ==like=>> 173
# 96 ==like=>> 239
# 96 ==like=>> 448
# 97 /1000
# 97 ==like=>> 185
# 97 ==like=>> 9
# 97 ==like=>> 336
# 97 ==like=>> 394
# 97 ==like=>> 163
# 98 /1000
# 99 /1000
# 99 ==like=>> 0
# 99 ==like=>> 32
# 99 ==like=>> 154
# 100 /1000
# 101 /1000
# 101 ==like=>> 2
# 101 ==like=>> 65
# 102 /1000
# 102 ==like=>> 322
# 102 ==like=>> 234
# 102 ==like=>> 179
# 102 ==like=>> 323
# 102 ==like=>> 25
# 102 ==like=>> 3
# 102 ==like=>> 120
# 103 /1000
# 103 ==like=>> 290
# 103 ==like=>> 411
# 103 ==like=>> 4
# 103 ==like=>> 131
# 103 ==like=>> 114
# 103 ==like=>> 125
# 103 ==like=>> 81
# 104 /1000
# 105 /1000
# 106 /1000
# 107 /1000
# 108 /1000
# 108 ==like=>> 9
# 108 ==like=>> 336
# 108 ==like=>> 152
# 108 ==like=>> 75
# 108 ==like=>> 292
# 108 ==like=>> 306
# 109 /1000
# 110 /1000
# 110 ==like=>> 352
# 110 ==like=>> 59
# 110 ==like=>> 328
# 110 ==like=>> 374
# 111 /1000
# 111 ==like=>> 188
# 111 ==like=>> 276
# 111 ==like=>> 1
# 111 ==like=>> 43
# 111 ==like=>> 430
# 111 ==like=>> 100
# 111 ==like=>> 408
# 111 ==like=>> 441
# 111 ==like=>> 310
# 112 /1000
# 113 /1000
# 113 ==like=>> 14
# 113 ==like=>> 246
# 113 ==like=>> 47
# 113 ==like=>> 3
# 113 ==like=>> 120
# 113 ==like=>> 37
# 113 ==like=>> 179
# 113 ==like=>> 333
# 113 ==like=>> 91
# 113 ==like=>> 25
# 113 ==like=>> 322
# 113 ==like=>> 102
# 113 ==like=>> 157
# 113 ==like=>> 344
# 113 ==like=>> 135
# 113 ==like=>> 399
# 113 ==like=>> 355
# 114 /1000
# 114 ==like=>> 290
# 114 ==like=>> 81
# 114 ==like=>> 180
# 114 ==like=>> 125
# 114 ==like=>> 257
# 114 ==like=>> 213
# 114 ==like=>> 334
# 114 ==like=>> 4
# 114 ==like=>> 131
# 114 ==like=>> 422
# 114 ==like=>> 367
# 115 /1000
# 116 /1000
# 117 /1000
# 118 /1000
# 119 /1000
# 120 /1000
# 120 ==like=>> 14
# 120 ==like=>> 25
# 120 ==like=>> 36
# 120 ==like=>> 47
# 120 ==like=>> 58
# 120 ==like=>> 69
# 120 ==like=>> 80
# 120 ==like=>> 91
# 120 ==like=>> 102
# 120 ==like=>> 113
# 120 ==like=>> 124
# 120 ==like=>> 135
# 120 ==like=>> 146
# 120 ==like=>> 157
# 120 ==like=>> 168
# 120 ==like=>> 179
# 120 ==like=>> 190
# 120 ==like=>> 212
# 120 ==like=>> 223
# 120 ==like=>> 234
# 120 ==like=>> 245
# 120 ==like=>> 256
# 120 ==like=>> 267
# 120 ==like=>> 278
# 120 ==like=>> 289
# 120 ==like=>> 300
# 120 ==like=>> 311
# 120 ==like=>> 322
# 120 ==like=>> 333
# 120 ==like=>> 344
# 120 ==like=>> 355
# 120 ==like=>> 366
# 120 ==like=>> 377
# 120 ==like=>> 388
# 120 ==like=>> 399
# 120 ==like=>> 410
# 120 ==like=>> 421
# 120 ==like=>> 432
# 120 ==like=>> 443
# 121 /1000
# 122 /1000
# 122 ==like=>> 210
# 122 ==like=>> 375
# 122 ==like=>> 59
# 122 ==like=>> 188
# 123 /1000
# 123 ==like=>> 2
# 123 ==like=>> 65
# 124 /1000
# 125 /1000
# 125 ==like=>> 81
# 125 ==like=>> 114
# 125 ==like=>> 257
# 125 ==like=>> 362
# 125 ==like=>> 444
# 125 ==like=>> 136
# 125 ==like=>> 4
# 125 ==like=>> 131
# 125 ==like=>> 312
# 125 ==like=>> 433
# 126 /1000
# 127 /1000
# 128 /1000
# 128 ==like=>> 145
# 128 ==like=>> 167
# 128 ==like=>> 420
# 129 /1000
# 130 /1000
# 130 ==like=>> 9
# 130 ==like=>> 336
# 131 /1000
# 131 ==like=>> 15
# 131 ==like=>> 26
# 131 ==like=>> 37
# 131 ==like=>> 59
# 131 ==like=>> 70
# 131 ==like=>> 81
# 131 ==like=>> 92
# 131 ==like=>> 114
# 131 ==like=>> 125
# 131 ==like=>> 136
# 131 ==like=>> 147
# 131 ==like=>> 180
# 131 ==like=>> 191
# 131 ==like=>> 202
# 131 ==like=>> 213
# 131 ==like=>> 224
# 131 ==like=>> 246
# 131 ==like=>> 257
# 131 ==like=>> 268
# 131 ==like=>> 279
# 131 ==like=>> 290
# 131 ==like=>> 301
# 131 ==like=>> 312
# 131 ==like=>> 323
# 131 ==like=>> 334
# 131 ==like=>> 345
# 131 ==like=>> 356
# 131 ==like=>> 367
# 131 ==like=>> 389
# 131 ==like=>> 400
# 131 ==like=>> 411
# 131 ==like=>> 422
# 131 ==like=>> 433
# 131 ==like=>> 444
# 132 /1000
# 132 ==like=>> 0
# 132 ==like=>> 32
# 132 ==like=>> 61
# 132 ==like=>> 330
# 133 /1000
# 134 /1000
# 134 ==like=>> 59
# 134 ==like=>> 35
# 135 /1000
# 135 ==like=>> 25
# 135 ==like=>> 333
# 135 ==like=>> 344
# 135 ==like=>> 91
# 135 ==like=>> 334
# 135 ==like=>> 234
# 135 ==like=>> 3
# 135 ==like=>> 120
# 135 ==like=>> 322
# 135 ==like=>> 113
# 135 ==like=>> 102
# 135 ==like=>> 256
# 135 ==like=>> 157
# 135 ==like=>> 355
# 136 /1000
# 136 ==like=>> 389
# 137 /1000
# 137 ==like=>> 45
# 137 ==like=>> 215
# 137 ==like=>> 41
# 137 ==like=>> 247
# 137 ==like=>> 10
# 137 ==like=>> 390
# 138 /1000
# 139 /1000
# 139 ==like=>> 7
# 139 ==like=>> 28
# 139 ==like=>> 59
# 140 /1000
# 141 /1000
# 141 ==like=>> 361
# 142 /1000
# 142 ==like=>> 67
# 142 ==like=>> 59
# 143 /1000
# 143 ==like=>> 329
# 144 /1000
# 144 ==like=>> 210
# 145 /1000
# 146 /1000
# 146 ==like=>> 15
# 146 ==like=>> 36
# 146 ==like=>> 379
# 146 ==like=>> 432
# 146 ==like=>> 3
# 146 ==like=>> 120
# 146 ==like=>> 368
# 147 /1000
# 147 ==like=>> 4
# 147 ==like=>> 131
# 148 /1000
# 149 /1000
# 149 ==like=>> 254
# 150 /1000
# 151 /1000
# 151 ==like=>> 30
# 151 ==like=>> 318
# 151 ==like=>> 59
# 151 ==like=>> 149
# 151 ==like=>> 6
# 151 ==like=>> 19
# 151 ==like=>> 53
# 151 ==like=>> 219
# 152 /1000
# 152 ==like=>> 75
# 152 ==like=>> 174
# 152 ==like=>> 9
# 152 ==like=>> 336
# 152 ==like=>> 163
# 152 ==like=>> 251
# 152 ==like=>> 240
# 152 ==like=>> 427
# 152 ==like=>> 64
# 152 ==like=>> 328
# 152 ==like=>> 108
# 153 /1000
# 154 /1000
# 154 ==like=>> 247
# 155 /1000
# 156 /1000
# 157 /1000
# 157 ==like=>> 14
# 157 ==like=>> 69
# 157 ==like=>> 289
# 157 ==like=>> 113
# 157 ==like=>> 256
# 157 ==like=>> 355
# 157 ==like=>> 25
# 157 ==like=>> 333
# 157 ==like=>> 135
# 158 /1000
# 158 ==like=>> 290
# 158 ==like=>> 4
# 158 ==like=>> 131
# 158 ==like=>> 257
# 158 ==like=>> 367
# 158 ==like=>> 202
# 159 /1000
# 160 /1000
# 160 ==like=>> 117
# 160 ==like=>> 373
# 160 ==like=>> 189
# 160 ==like=>> 343
# 160 ==like=>> 227
# 161 /1000
# 162 /1000
# 162 ==like=>> 62
# 162 ==like=>> 8
# 162 ==like=>> 72
# 162 ==like=>> 40
# 163 /1000
# 163 ==like=>> 42
# 163 ==like=>> 31
# 163 ==like=>> 229
# 163 ==like=>> 251
# 163 ==like=>> 174
# 163 ==like=>> 9
# 163 ==like=>> 336
# 163 ==like=>> 152
# 164 /1000
# 165 /1000
# 166 /1000
# 166 ==like=>> 408
# 167 /1000
# 167 ==like=>> 431
# 167 ==like=>> 16
# 167 ==like=>> 222
# 167 ==like=>> 212
# 167 ==like=>> 387
# 167 ==like=>> 255
# 168 /1000
# 169 /1000
# 169 ==like=>> 4
# 169 ==like=>> 131
# 169 ==like=>> 367
# 169 ==like=>> 344
# 170 /1000
# 170 ==like=>> 318
# 170 ==like=>> 274
# 171 /1000
# 171 ==like=>> 17
# 171 ==like=>> 6
# 171 ==like=>> 19
# 171 ==like=>> 53
# 171 ==like=>> 219
# 171 ==like=>> 30
# 171 ==like=>> 7
# 171 ==like=>> 28
# 172 /1000
# 172 ==like=>> 59
# 173 /1000
# 173 ==like=>> 217
# 173 ==like=>> 107
# 173 ==like=>> 96
# 173 ==like=>> 239
# 173 ==like=>> 206
# 173 ==like=>> 448
# 173 ==like=>> 8
# 173 ==like=>> 72
# 173 ==like=>> 349
# 173 ==like=>> 250
# 174 /1000
# 174 ==like=>> 372
# 174 ==like=>> 86
# 174 ==like=>> 240
# 174 ==like=>> 163
# 174 ==like=>> 9
# 174 ==like=>> 336
# 174 ==like=>> 152
# 175 /1000
# 176 /1000
# 176 ==like=>> 59
# 177 /1000
# 177 ==like=>> 421
# 178 /1000
# 179 /1000
# 179 ==like=>> 14
# 179 ==like=>> 113
# 179 ==like=>> 256
# 179 ==like=>> 91
# 180 /1000
# 180 ==like=>> 422
# 180 ==like=>> 125
# 180 ==like=>> 400
# 180 ==like=>> 4
# 180 ==like=>> 131
# 180 ==like=>> 114
# 180 ==like=>> 246
# 180 ==like=>> 334
# 180 ==like=>> 367
# 180 ==like=>> 344
# 180 ==like=>> 421
# 180 ==like=>> 202
# 181 /1000
# 182 /1000
# 182 ==like=>> 382
# 182 ==like=>> 6
# 182 ==like=>> 19
# 182 ==like=>> 53
# 182 ==like=>> 219
# 183 /1000
# 184 /1000
# 184 ==like=>> 320
# 184 ==like=>> 10
# 184 ==like=>> 390
# 184 ==like=>> 274
# 184 ==like=>> 61
# 184 ==like=>> 382
# 184 ==like=>> 6
# 184 ==like=>> 19
# 184 ==like=>> 53
# 184 ==like=>> 219
# 185 /1000
# 185 ==like=>> 31
# 185 ==like=>> 42
# 185 ==like=>> 97
# 185 ==like=>> 9
# 185 ==like=>> 336
# 185 ==like=>> 292
# 186 /1000
# 186 ==like=>> 16
# 186 ==like=>> 27
# 186 ==like=>> 38
# 186 ==like=>> 49
# 186 ==like=>> 60
# 186 ==like=>> 71
# 186 ==like=>> 82
# 186 ==like=>> 93
# 186 ==like=>> 115
# 186 ==like=>> 126
# 186 ==like=>> 137
# 186 ==like=>> 159
# 186 ==like=>> 170
# 186 ==like=>> 192
# 186 ==like=>> 203
# 186 ==like=>> 214
# 186 ==like=>> 236
# 186 ==like=>> 247
# 186 ==like=>> 258
# 186 ==like=>> 269
# 186 ==like=>> 291
# 186 ==like=>> 302
# 186 ==like=>> 313
# 186 ==like=>> 324
# 186 ==like=>> 335
# 186 ==like=>> 346
# 186 ==like=>> 357
# 186 ==like=>> 368
# 186 ==like=>> 379
# 186 ==like=>> 10
# 186 ==like=>> 390
# 186 ==like=>> 401
# 186 ==like=>> 412
# 186 ==like=>> 423
# 186 ==like=>> 445
# 186 ==like=>> 59
# 186 ==like=>> 254
# 186 ==like=>> 343
# 186 ==like=>> 67
# 186 ==like=>> 61
# 186 ==like=>> 298
# 186 ==like=>> 39
# 186 ==like=>> 314
# 186 ==like=>> 382
# 186 ==like=>> 154
# 187 /1000
# 188 /1000
# 188 ==like=>> 49
# 188 ==like=>> 397
# 188 ==like=>> 111
# 188 ==like=>> 320
# 189 /1000
# 190 /1000
# 190 ==like=>> 59
# 190 ==like=>> 289
# 190 ==like=>> 69
# 190 ==like=>> 322
# 190 ==like=>> 102
# 190 ==like=>> 377
# 190 ==like=>> 421
# 190 ==like=>> 399
# 190 ==like=>> 334
# 190 ==like=>> 256
# 190 ==like=>> 344
# 190 ==like=>> 135
# 190 ==like=>> 3
# 190 ==like=>> 120
# 190 ==like=>> 25
# 190 ==like=>> 278
# 190 ==like=>> 300
# 191 /1000
# 191 ==like=>> 4
# 191 ==like=>> 131
# 191 ==like=>> 125
# 191 ==like=>> 422
# 191 ==like=>> 334
# 192 /1000
# 193 /1000
# 193 ==like=>> 6
# 193 ==like=>> 19
# 193 ==like=>> 53
# 193 ==like=>> 219
# 193 ==like=>> 254
# 194 /1000
# 195 /1000
# 196 /1000
# 197 /1000
# 198 /1000
# 198 ==like=>> 0
# 198 ==like=>> 32
# 198 ==like=>> 195
# 198 ==like=>> 320
# 199 /1000
# 199 ==like=>> 59
# 199 ==like=>> 144
# 199 ==like=>> 375
# 199 ==like=>> 320
# 199 ==like=>> 188
# 199 ==like=>> 210
# 199 ==like=>> 1
# 199 ==like=>> 43
# 199 ==like=>> 276
# 199 ==like=>> 430
# 199 ==like=>> 441
# 200 /1000
# 201 /1000
# 201 ==like=>> 14
# 201 ==like=>> 59
# 201 ==like=>> 289
# 201 ==like=>> 322
# 201 ==like=>> 168
# 201 ==like=>> 179
# 201 ==like=>> 377
# 201 ==like=>> 3
# 201 ==like=>> 120
# 201 ==like=>> 323
# 201 ==like=>> 113
# 201 ==like=>> 355
# 201 ==like=>> 399
# 201 ==like=>> 91
# 201 ==like=>> 267
# 201 ==like=>> 102
# 201 ==like=>> 344
# 202 /1000
# 202 ==like=>> 4
# 202 ==like=>> 131
# 202 ==like=>> 180
# 203 /1000
# 204 /1000
# 204 ==like=>> 6
# 204 ==like=>> 19
# 204 ==like=>> 53
# 204 ==like=>> 219
# 204 ==like=>> 240
# 204 ==like=>> 17
# 204 ==like=>> 64
# 204 ==like=>> 108
# 204 ==like=>> 328
# 205 /1000
# 205 ==like=>> 302
# 205 ==like=>> 320
# 206 /1000
# 206 ==like=>> 173
# 206 ==like=>> 8
# 206 ==like=>> 72
# 206 ==like=>> 239
# 206 ==like=>> 228
# 206 ==like=>> 217
# 206 ==like=>> 448
# 206 ==like=>> 44
# 206 ==like=>> 384
# 206 ==like=>> 417
# 206 ==like=>> 71
# 206 ==like=>> 395
# 207 /1000
# 208 /1000
# 209 /1000
# 209 ==like=>> 0
# 209 ==like=>> 32
# 210 /1000
# 210 ==like=>> 188
# 210 ==like=>> 320
# 210 ==like=>> 144
# 210 ==like=>> 199
# 210 ==like=>> 276
# 210 ==like=>> 1
# 210 ==like=>> 43
# 210 ==like=>> 221
# 210 ==like=>> 309
# 210 ==like=>> 109
# 211 /1000
# 212 /1000
# 213 /1000
# 213 ==like=>> 4
# 213 ==like=>> 131
# 213 ==like=>> 257
# 213 ==like=>> 422
# 213 ==like=>> 367
# 214 /1000
# 214 ==like=>> 61
# 215 /1000
# 215 ==like=>> 274
# 215 ==like=>> 117
# 215 ==like=>> 320
# 215 ==like=>> 153
# 215 ==like=>> 71
# 215 ==like=>> 6
# 215 ==like=>> 19
# 215 ==like=>> 53
# 215 ==like=>> 219
# 215 ==like=>> 137
# 215 ==like=>> 382
# 216 /1000
# 216 ==like=>> 348
# 217 /1000
# 218 /1000
# 218 ==like=>> 174
# 218 ==like=>> 9
# 218 ==like=>> 336
# 219 /1000
# 219 ==like=>> 17
# 219 ==like=>> 7
# 219 ==like=>> 28
# 219 ==like=>> 39
# 219 ==like=>> 50
# 219 ==like=>> 61
# 219 ==like=>> 8
# 219 ==like=>> 72
# 219 ==like=>> 94
# 219 ==like=>> 116
# 219 ==like=>> 127
# 219 ==like=>> 138
# 219 ==like=>> 149
# 219 ==like=>> 160
# 219 ==like=>> 171
# 219 ==like=>> 182
# 219 ==like=>> 204
# 219 ==like=>> 215
# 219 ==like=>> 226
# 219 ==like=>> 248
# 219 ==like=>> 270
# 219 ==like=>> 281
# 219 ==like=>> 292
# 219 ==like=>> 303
# 219 ==like=>> 314
# 219 ==like=>> 325
# 219 ==like=>> 9
# 219 ==like=>> 336
# 219 ==like=>> 347
# 219 ==like=>> 358
# 219 ==like=>> 369
# 219 ==like=>> 380
# 219 ==like=>> 391
# 219 ==like=>> 402
# 219 ==like=>> 413
# 219 ==like=>> 424
# 219 ==like=>> 446
# 219 ==like=>> 302
# 219 ==like=>> 59
# 219 ==like=>> 272
# 219 ==like=>> 151
# 220 /1000
# 221 /1000
# 221 ==like=>> 375
# 221 ==like=>> 144
# 221 ==like=>> 430
# 221 ==like=>> 188
# 221 ==like=>> 210
# 221 ==like=>> 1
# 221 ==like=>> 43
# 221 ==like=>> 276
# 222 /1000
# 222 ==like=>> 167
# 222 ==like=>> 79
# 223 /1000
# 223 ==like=>> 179
# 223 ==like=>> 323
# 223 ==like=>> 289
# 223 ==like=>> 334
# 223 ==like=>> 102
# 223 ==like=>> 3
# 223 ==like=>> 120
# 224 /1000
# 224 ==like=>> 4
# 224 ==like=>> 131
# 225 /1000
# 226 /1000
# 226 ==like=>> 347
# 227 /1000
# 227 ==like=>> 35
# 227 ==like=>> 248
# 228 /1000
# 229 /1000
# 230 /1000
# 230 ==like=>> 270
# 230 ==like=>> 59
# 230 ==like=>> 195
# 230 ==like=>> 67
# 230 ==like=>> 363
# 230 ==like=>> 71
# 230 ==like=>> 187
# 231 /1000
# 232 /1000
# 233 /1000
# 233 ==like=>> 211
# 234 /1000
# 234 ==like=>> 421
# 234 ==like=>> 102
# 234 ==like=>> 135
# 235 /1000
# 236 /1000
# 236 ==like=>> 82
# 236 ==like=>> 153
# 236 ==like=>> 85
# 237 /1000
# 237 ==like=>> 6
# 237 ==like=>> 19
# 237 ==like=>> 53
# 237 ==like=>> 219
# 237 ==like=>> 71
# 238 /1000
# 238 ==like=>> 189
# 239 /1000
# 240 /1000
# 241 /1000
# 241 ==like=>> 251
# 241 ==like=>> 67
# 242 /1000
# 242 ==like=>> 195
# 242 ==like=>> 437
# 243 /1000
# 243 ==like=>> 166
# 243 ==like=>> 1
# 243 ==like=>> 43
# 243 ==like=>> 441
# 243 ==like=>> 122
# 243 ==like=>> 34
# 244 /1000
# 245 /1000
# 245 ==like=>> 14
# 245 ==like=>> 59
# 245 ==like=>> 355
# 245 ==like=>> 344
# 245 ==like=>> 3
# 245 ==like=>> 120
# 245 ==like=>> 289
# 245 ==like=>> 25
# 246 /1000
# 246 ==like=>> 301
# 246 ==like=>> 59
# 246 ==like=>> 389
# 246 ==like=>> 4
# 246 ==like=>> 131
# 246 ==like=>> 81
# 246 ==like=>> 345
# 246 ==like=>> 422
# 246 ==like=>> 268
# 247 /1000
# 248 /1000
# 248 ==like=>> 6
# 248 ==like=>> 19
# 248 ==like=>> 53
# 248 ==like=>> 219
# 248 ==like=>> 151
# 248 ==like=>> 227
# 249 /1000
# 249 ==like=>> 59
# 249 ==like=>> 189
# 250 /1000
# 250 ==like=>> 173
# 250 ==like=>> 8
# 250 ==like=>> 72
# 250 ==like=>> 349
# 250 ==like=>> 448
# 251 /1000
# 251 ==like=>> 317
# 251 ==like=>> 20
# 251 ==like=>> 163
# 251 ==like=>> 152
# 251 ==like=>> 295
# 251 ==like=>> 75
# 252 /1000
# 252 ==like=>> 67
# 252 ==like=>> 360
# 253 /1000
# 253 ==like=>> 0
# 253 ==like=>> 32
# 253 ==like=>> 343
# 253 ==like=>> 112
# 254 /1000
# 254 ==like=>> 320
# 255 /1000
# 256 /1000
# 256 ==like=>> 322
# 256 ==like=>> 246
# 256 ==like=>> 323
# 256 ==like=>> 179
# 256 ==like=>> 59
# 256 ==like=>> 3
# 256 ==like=>> 120
# 256 ==like=>> 344
# 256 ==like=>> 102
# 256 ==like=>> 157
# 256 ==like=>> 135
# 256 ==like=>> 267
# 257 /1000
# 257 ==like=>> 92
# 257 ==like=>> 290
# 257 ==like=>> 367
# 257 ==like=>> 81
# 257 ==like=>> 213
# 257 ==like=>> 4
# 257 ==like=>> 131
# 257 ==like=>> 114
# 257 ==like=>> 125
# 257 ==like=>> 422
# 258 /1000
# 258 ==like=>> 10
# 258 ==like=>> 390
# 259 /1000
# 259 ==like=>> 6
# 259 ==like=>> 19
# 259 ==like=>> 53
# 259 ==like=>> 219
# 260 /1000
# 260 ==like=>> 446
# 260 ==like=>> 236
# 260 ==like=>> 442
# 261 /1000
# 261 ==like=>> 7
# 261 ==like=>> 28
# 261 ==like=>> 17
# 261 ==like=>> 320
# 261 ==like=>> 382
# 261 ==like=>> 254
# 261 ==like=>> 59
# 262 /1000
# 262 ==like=>> 9
# 262 ==like=>> 336
# 262 ==like=>> 295
# 262 ==like=>> 416
# 262 ==like=>> 97
# 263 /1000
# 263 ==like=>> 111
# 263 ==like=>> 67
# 263 ==like=>> 199
# 264 /1000
# 265 /1000
# 265 ==like=>> 61
# 265 ==like=>> 38
# 266 /1000
# 267 /1000
# 267 ==like=>> 289
# 267 ==like=>> 59
# 267 ==like=>> 234
# 267 ==like=>> 25
# 267 ==like=>> 399
# 267 ==like=>> 278
# 267 ==like=>> 322
# 268 /1000
# 268 ==like=>> 422
# 268 ==like=>> 406
# 268 ==like=>> 4
# 268 ==like=>> 131
# 268 ==like=>> 36
# 268 ==like=>> 421
# 269 /1000
# 270 /1000
# 270 ==like=>> 59
# 271 /1000
# 271 ==like=>> 348
# 271 ==like=>> 216
# 272 /1000
# 273 /1000
# 274 /1000
# 274 ==like=>> 215
# 274 ==like=>> 391
# 274 ==like=>> 89
# 274 ==like=>> 439
# 274 ==like=>> 61
# 274 ==like=>> 302
# 274 ==like=>> 67
# 274 ==like=>> 320
# 274 ==like=>> 407
# 274 ==like=>> 236
# 274 ==like=>> 82
# 275 /1000
# 276 /1000
# 276 ==like=>> 419
# 276 ==like=>> 10
# 276 ==like=>> 390
# 276 ==like=>> 89
# 276 ==like=>> 111
# 276 ==like=>> 59
# 276 ==like=>> 188
# 276 ==like=>> 210
# 276 ==like=>> 373
# 276 ==like=>> 430
# 276 ==like=>> 375
# 276 ==like=>> 199
# 276 ==like=>> 122
# 276 ==like=>> 221
# 277 /1000
# 277 ==like=>> 431
# 277 ==like=>> 112
# 277 ==like=>> 68
# 278 /1000
# 278 ==like=>> 69
# 278 ==like=>> 80
# 278 ==like=>> 37
# 278 ==like=>> 179
# 278 ==like=>> 92
# 278 ==like=>> 322
# 278 ==like=>> 234
# 278 ==like=>> 345
# 278 ==like=>> 58
# 278 ==like=>> 399
# 278 ==like=>> 190
# 278 ==like=>> 267
# 278 ==like=>> 256
# 278 ==like=>> 443
# 278 ==like=>> 102
# 278 ==like=>> 113
# 278 ==like=>> 334
# 278 ==like=>> 289
# 278 ==like=>> 432
# 278 ==like=>> 3
# 278 ==like=>> 120
# 278 ==like=>> 223
# 278 ==like=>> 344
# 279 /1000
# 279 ==like=>> 4
# 279 ==like=>> 131
# 280 /1000
# 280 ==like=>> 189
# 281 /1000
# 282 /1000
# 282 ==like=>> 446
# 283 /1000
# 284 /1000
# 284 ==like=>> 20
# 284 ==like=>> 31
# 284 ==like=>> 75
# 284 ==like=>> 317
# 285 /1000
# 285 ==like=>> 67
# 286 /1000
# 286 ==like=>> 55
# 287 /1000
# 287 ==like=>> 145
# 288 /1000
# 289 /1000
# 289 ==like=>> 14
# 289 ==like=>> 59
# 289 ==like=>> 179
# 289 ==like=>> 190
# 289 ==like=>> 80
# 289 ==like=>> 69
# 289 ==like=>> 399
# 289 ==like=>> 322
# 289 ==like=>> 3
# 289 ==like=>> 120
# 289 ==like=>> 278
# 289 ==like=>> 334
# 290 /1000
# 290 ==like=>> 114
# 290 ==like=>> 257
# 290 ==like=>> 4
# 290 ==like=>> 131
# 290 ==like=>> 411
# 290 ==like=>> 301
# 290 ==like=>> 389
# 290 ==like=>> 213
# 291 /1000
# 291 ==like=>> 71
# 291 ==like=>> 204
# 291 ==like=>> 151
# 292 /1000
# 292 ==like=>> 6
# 292 ==like=>> 19
# 292 ==like=>> 53
# 292 ==like=>> 219
# 292 ==like=>> 9
# 292 ==like=>> 336
# 292 ==like=>> 416
# 292 ==like=>> 185
# 293 /1000
# 293 ==like=>> 52
# 293 ==like=>> 440
# 293 ==like=>> 71
# 294 /1000
# 294 ==like=>> 448
# 294 ==like=>> 8
# 294 ==like=>> 72
# 295 /1000
# 295 ==like=>> 251
# 295 ==like=>> 262
# 295 ==like=>> 174
# 295 ==like=>> 273
# 295 ==like=>> 9
# 295 ==like=>> 336
# 295 ==like=>> 64
# 295 ==like=>> 328
# 295 ==like=>> 416
# 295 ==like=>> 427
# 295 ==like=>> 185
# 296 /1000
# 297 /1000
# 297 ==like=>> 212
# 297 ==like=>> 442
# 298 /1000
# 299 /1000
# 300 /1000
# 300 ==like=>> 59
# 300 ==like=>> 344
# 300 ==like=>> 179
# 300 ==like=>> 355
# 300 ==like=>> 322
# 300 ==like=>> 190
# 300 ==like=>> 80
# 300 ==like=>> 399
# 300 ==like=>> 377
# 300 ==like=>> 410
# 300 ==like=>> 366
# 300 ==like=>> 388
# 300 ==like=>> 278
# 300 ==like=>> 135
# 300 ==like=>> 157
# 300 ==like=>> 333
# 300 ==like=>> 3
# 300 ==like=>> 120
# 300 ==like=>> 25
# 301 /1000
# 301 ==like=>> 246
# 301 ==like=>> 234
# 301 ==like=>> 4
# 301 ==like=>> 131
# 301 ==like=>> 433
# 301 ==like=>> 367
# 301 ==like=>> 37
# 302 /1000
# 302 ==like=>> 363
# 302 ==like=>> 270
# 302 ==like=>> 407
# 302 ==like=>> 6
# 302 ==like=>> 19
# 302 ==like=>> 53
# 302 ==like=>> 219
# 302 ==like=>> 205
# 302 ==like=>> 274
# 303 /1000
# 303 ==like=>> 343
# 303 ==like=>> 6
# 303 ==like=>> 19
# 303 ==like=>> 53
# 303 ==like=>> 219
# 304 /1000
# 305 /1000
# 306 /1000
# 306 ==like=>> 163
# 306 ==like=>> 64
# 306 ==like=>> 9
# 306 ==like=>> 336
# 306 ==like=>> 108
# 306 ==like=>> 328
# 307 /1000
# 308 /1000
# 309 /1000
# 309 ==like=>> 210
# 309 ==like=>> 276
# 309 ==like=>> 1
# 309 ==like=>> 43
# 310 /1000
# 311 /1000
# 312 /1000
# 312 ==like=>> 81
# 312 ==like=>> 4
# 312 ==like=>> 131
# 312 ==like=>> 125
# 312 ==like=>> 246
# 313 /1000
# 314 /1000
# 314 ==like=>> 7
# 314 ==like=>> 28
# 314 ==like=>> 17
# 314 ==like=>> 6
# 314 ==like=>> 19
# 314 ==like=>> 53
# 314 ==like=>> 219
# 314 ==like=>> 10
# 314 ==like=>> 390
# 314 ==like=>> 247
# 314 ==like=>> 62
# 315 /1000
# 316 /1000
# 316 ==like=>> 8
# 316 ==like=>> 72
# 317 /1000
# 317 ==like=>> 251
# 317 ==like=>> 64
# 317 ==like=>> 9
# 317 ==like=>> 336
# 317 ==like=>> 416
# 317 ==like=>> 328
# 317 ==like=>> 108
# 318 /1000
# 319 /1000
# 320 /1000
# 320 ==like=>> 188
# 320 ==like=>> 85
# 321 /1000
# 321 ==like=>> 329
# 321 ==like=>> 310
# 322 /1000
# 322 ==like=>> 14
# 322 ==like=>> 59
# 322 ==like=>> 80
# 322 ==like=>> 256
# 322 ==like=>> 69
# 322 ==like=>> 157
# 322 ==like=>> 102
# 322 ==like=>> 37
# 322 ==like=>> 289
# 322 ==like=>> 399
# 322 ==like=>> 190
# 322 ==like=>> 300
# 322 ==like=>> 377
# 322 ==like=>> 3
# 322 ==like=>> 120
# 322 ==like=>> 333
# 322 ==like=>> 113
# 322 ==like=>> 355
# 322 ==like=>> 135
# 322 ==like=>> 344
# 323 /1000
# 323 ==like=>> 4
# 323 ==like=>> 131
# 323 ==like=>> 91
# 323 ==like=>> 234
# 323 ==like=>> 433
# 323 ==like=>> 15
# 323 ==like=>> 256
# 323 ==like=>> 355
# 323 ==like=>> 3
# 323 ==like=>> 120
# 323 ==like=>> 102
# 323 ==like=>> 377
# 324 /1000
# 324 ==like=>> 212
# 325 /1000
# 326 /1000
# 326 ==like=>> 7
# 326 ==like=>> 28
# 326 ==like=>> 236
# 326 ==like=>> 320
# 326 ==like=>> 52
# 326 ==like=>> 440
# 326 ==like=>> 62
# 326 ==like=>> 71
# 327 /1000
# 327 ==like=>> 52
# 327 ==like=>> 440
# 327 ==like=>> 382
# 327 ==like=>> 173
# 327 ==like=>> 96
# 327 ==like=>> 228
# 327 ==like=>> 217
# 327 ==like=>> 239
# 327 ==like=>> 349
# 327 ==like=>> 8
# 327 ==like=>> 72
# 327 ==like=>> 448
# 328 /1000
# 328 ==like=>> 174
# 328 ==like=>> 61
# 329 /1000
# 329 ==like=>> 143
# 330 /1000
# 331 /1000
# 331 ==like=>> 255
# 331 ==like=>> 244
# 332 /1000
# 333 /1000
# 333 ==like=>> 14
# 333 ==like=>> 25
# 333 ==like=>> 399
# 333 ==like=>> 113
# 333 ==like=>> 322
# 333 ==like=>> 334
# 333 ==like=>> 278
# 333 ==like=>> 3
# 333 ==like=>> 120
# 333 ==like=>> 289
# 333 ==like=>> 344
# 334 /1000
# 334 ==like=>> 14
# 334 ==like=>> 4
# 334 ==like=>> 131
# 334 ==like=>> 92
# 334 ==like=>> 422
# 334 ==like=>> 15
# 334 ==like=>> 135
# 334 ==like=>> 345
# 334 ==like=>> 223
# 334 ==like=>> 344
# 334 ==like=>> 333
# 334 ==like=>> 289
# 334 ==like=>> 278
# 334 ==like=>> 355
# 334 ==like=>> 157
# 335 /1000
# 336 /1000
# 336 ==like=>> 20
# 336 ==like=>> 31
# 336 ==like=>> 42
# 336 ==like=>> 6
# 336 ==like=>> 19
# 336 ==like=>> 53
# 336 ==like=>> 219
# 336 ==like=>> 64
# 336 ==like=>> 75
# 336 ==like=>> 86
# 336 ==like=>> 97
# 336 ==like=>> 108
# 336 ==like=>> 130
# 336 ==like=>> 141
# 336 ==like=>> 152
# 336 ==like=>> 163
# 336 ==like=>> 174
# 336 ==like=>> 185
# 336 ==like=>> 196
# 336 ==like=>> 207
# 336 ==like=>> 218
# 336 ==like=>> 229
# 336 ==like=>> 240
# 336 ==like=>> 251
# 336 ==like=>> 262
# 336 ==like=>> 273
# 336 ==like=>> 295
# 336 ==like=>> 306
# 336 ==like=>> 317
# 336 ==like=>> 328
# 336 ==like=>> 339
# 336 ==like=>> 350
# 336 ==like=>> 361
# 336 ==like=>> 372
# 336 ==like=>> 394
# 336 ==like=>> 405
# 336 ==like=>> 416
# 336 ==like=>> 427
# 336 ==like=>> 438
# 337 /1000
# 337 ==like=>> 275
# 338 /1000
# 339 /1000
# 339 ==like=>> 416
# 339 ==like=>> 64
# 339 ==like=>> 427
# 339 ==like=>> 9
# 339 ==like=>> 336
# 339 ==like=>> 328
# 339 ==like=>> 361
# 340 /1000
# 340 ==like=>> 67
# 340 ==like=>> 153
# 340 ==like=>> 61
# 341 /1000
# 341 ==like=>> 374
# 342 /1000
# 342 ==like=>> 59
# 342 ==like=>> 100
# 342 ==like=>> 441
# 342 ==like=>> 430
# 342 ==like=>> 1
# 342 ==like=>> 43
# 342 ==like=>> 364
# 342 ==like=>> 419
# 342 ==like=>> 310
# 343 /1000
# 344 /1000
# 344 ==like=>> 14
# 344 ==like=>> 180
# 344 ==like=>> 15
# 344 ==like=>> 179
# 344 ==like=>> 37
# 344 ==like=>> 377
# 344 ==like=>> 69
# 345 /1000
# 345 ==like=>> 81
# 345 ==like=>> 400
# 345 ==like=>> 37
# 345 ==like=>> 4
# 345 ==like=>> 131
# 346 /1000
# 346 ==like=>> 357
# 347 /1000
# 348 /1000
# 348 ==like=>> 49
# 348 ==like=>> 7
# 348 ==like=>> 28
# 348 ==like=>> 359
# 349 /1000
# 349 ==like=>> 173
# 349 ==like=>> 283
# 349 ==like=>> 8
# 349 ==like=>> 72
# 349 ==like=>> 448
# 349 ==like=>> 217
# 349 ==like=>> 107
# 350 /1000
# 351 /1000
# 352 /1000
# 352 ==like=>> 431
# 352 ==like=>> 154
# 353 /1000
# 353 ==like=>> 111
# 353 ==like=>> 342
# 353 ==like=>> 1
# 353 ==like=>> 43
# 354 /1000
# 354 ==like=>> 79
# 355 /1000
# 355 ==like=>> 14
# 355 ==like=>> 300
# 355 ==like=>> 37
# 355 ==like=>> 80
# 355 ==like=>> 69
# 355 ==like=>> 323
# 355 ==like=>> 245
# 355 ==like=>> 3
# 355 ==like=>> 120
# 355 ==like=>> 322
# 355 ==like=>> 399
# 355 ==like=>> 334
# 355 ==like=>> 289
# 356 /1000
# 356 ==like=>> 334
# 356 ==like=>> 4
# 356 ==like=>> 131
# 356 ==like=>> 157
# 356 ==like=>> 421
# 356 ==like=>> 345
# 356 ==like=>> 135
# 356 ==like=>> 36
# 356 ==like=>> 422
# 356 ==like=>> 389
# 357 /1000
# 358 /1000
# 359 /1000
# 359 ==like=>> 7
# 359 ==like=>> 28
# 359 ==like=>> 291
# 359 ==like=>> 161
# 360 /1000
# 360 ==like=>> 247
# 360 ==like=>> 437
# 360 ==like=>> 10
# 360 ==like=>> 390
# 360 ==like=>> 4
# 360 ==like=>> 131
# 360 ==like=>> 59
# 360 ==like=>> 358
# 360 ==like=>> 49
# 360 ==like=>> 274
# 360 ==like=>> 314
# 360 ==like=>> 252
# 360 ==like=>> 320
# 360 ==like=>> 153
# 361 /1000
# 361 ==like=>> 64
# 361 ==like=>> 328
# 361 ==like=>> 9
# 361 ==like=>> 336
# 361 ==like=>> 163
# 361 ==like=>> 339
# 361 ==like=>> 317
# 361 ==like=>> 141
# 362 /1000
# 362 ==like=>> 14
# 363 /1000
# 363 ==like=>> 0
# 363 ==like=>> 32
# 363 ==like=>> 407
# 364 /1000
# 364 ==like=>> 1
# 364 ==like=>> 43
# 364 ==like=>> 342
# 365 /1000
# 366 /1000
# 366 ==like=>> 344
# 366 ==like=>> 3
# 366 ==like=>> 120
# 366 ==like=>> 300
# 366 ==like=>> 377
# 366 ==like=>> 388
# 367 /1000
# 367 ==like=>> 59
# 367 ==like=>> 4
# 367 ==like=>> 131
# 367 ==like=>> 389
# 368 /1000
# 368 ==like=>> 346
# 368 ==like=>> 146
# 369 /1000
# 369 ==like=>> 59
# 370 /1000
# 371 /1000
# 372 /1000
# 372 ==like=>> 306
# 372 ==like=>> 328
# 373 /1000
# 373 ==like=>> 352
# 374 /1000
# 374 ==like=>> 154
# 374 ==like=>> 341
# 375 /1000
# 375 ==like=>> 122
# 375 ==like=>> 221
# 375 ==like=>> 397
# 375 ==like=>> 199
# 375 ==like=>> 188
# 375 ==like=>> 276
# 375 ==like=>> 320
# 375 ==like=>> 1
# 375 ==like=>> 43
# 375 ==like=>> 441
# 375 ==like=>> 430
# 376 /1000
# 377 /1000
# 377 ==like=>> 14
# 377 ==like=>> 69
# 377 ==like=>> 59
# 377 ==like=>> 406
# 377 ==like=>> 245
# 377 ==like=>> 15
# 377 ==like=>> 37
# 377 ==like=>> 168
# 377 ==like=>> 179
# 377 ==like=>> 355
# 377 ==like=>> 323
# 377 ==like=>> 344
# 377 ==like=>> 388
# 377 ==like=>> 300
# 377 ==like=>> 399
# 377 ==like=>> 322
# 377 ==like=>> 278
# 377 ==like=>> 113
# 377 ==like=>> 333
# 377 ==like=>> 366
# 377 ==like=>> 3
# 377 ==like=>> 120
# 378 /1000
# 378 ==like=>> 345
# 378 ==like=>> 4
# 378 ==like=>> 131
# 378 ==like=>> 389
# 379 /1000
# 379 ==like=>> 36
# 379 ==like=>> 357
# 379 ==like=>> 346
# 379 ==like=>> 146
# 380 /1000
# 380 ==like=>> 30
# 380 ==like=>> 6
# 380 ==like=>> 19
# 380 ==like=>> 53
# 380 ==like=>> 219
# 380 ==like=>> 52
# 380 ==like=>> 440
# 381 /1000
# 382 /1000
# 382 ==like=>> 261
# 382 ==like=>> 215
# 382 ==like=>> 182
# 382 ==like=>> 404
# 382 ==like=>> 41
# 382 ==like=>> 228
# 382 ==like=>> 151
# 382 ==like=>> 49
# 382 ==like=>> 448
# 382 ==like=>> 117
# 382 ==like=>> 89
# 383 /1000
# 384 /1000
# 384 ==like=>> 59
# 384 ==like=>> 358
# 384 ==like=>> 61
# 384 ==like=>> 272
# 384 ==like=>> 283
# 384 ==like=>> 382
# 384 ==like=>> 274
# 385 /1000
# 386 /1000
# 387 /1000
# 388 /1000
# 389 /1000
# 389 ==like=>> 411
# 389 ==like=>> 246
# 389 ==like=>> 345
# 389 ==like=>> 268
# 389 ==like=>> 356
# 390 /1000
# 391 /1000
# 391 ==like=>> 6
# 391 ==like=>> 19
# 391 ==like=>> 53
# 391 ==like=>> 219
# 391 ==like=>> 274
# 391 ==like=>> 413
# 392 /1000
# 393 /1000
# 394 /1000
# 394 ==like=>> 97
# 394 ==like=>> 64
# 394 ==like=>> 416
# 394 ==like=>> 328
# 394 ==like=>> 9
# 394 ==like=>> 336
# 395 /1000
# 395 ==like=>> 365
# 396 /1000
# 397 /1000
# 398 /1000
# 399 /1000
# 399 ==like=>> 14
# 399 ==like=>> 59
# 399 ==like=>> 80
# 399 ==like=>> 179
# 399 ==like=>> 377
# 399 ==like=>> 168
# 399 ==like=>> 69
# 399 ==like=>> 421
# 399 ==like=>> 322
# 399 ==like=>> 300
# 399 ==like=>> 410
# 399 ==like=>> 289
# 399 ==like=>> 190
# 399 ==like=>> 333
# 399 ==like=>> 278
# 399 ==like=>> 3
# 399 ==like=>> 120
# 399 ==like=>> 267
# 399 ==like=>> 25
# 399 ==like=>> 344
# 399 ==like=>> 113
# 399 ==like=>> 245
# 399 ==like=>> 355
# 399 ==like=>> 91
# 399 ==like=>> 157
# 400 /1000
# 401 /1000
# 402 /1000
# 403 /1000
# 403 ==like=>> 446
# 404 /1000
# 404 ==like=>> 371
# 404 ==like=>> 382
# 404 ==like=>> 52
# 404 ==like=>> 440
# 404 ==like=>> 71
# 404 ==like=>> 8
# 404 ==like=>> 72
# 404 ==like=>> 415
# 405 /1000
# 405 ==like=>> 328
# 405 ==like=>> 427
# 405 ==like=>> 185
# 405 ==like=>> 9
# 405 ==like=>> 336
# 406 /1000
# 407 /1000
# 407 ==like=>> 302
# 407 ==like=>> 0
# 407 ==like=>> 32
# 407 ==like=>> 247
# 407 ==like=>> 76
# 408 /1000
# 409 /1000
# 409 ==like=>> 431
# 410 /1000
# 410 ==like=>> 234
# 410 ==like=>> 3
# 410 ==like=>> 120
# 410 ==like=>> 399
# 410 ==like=>> 300
# 410 ==like=>> 388
# 410 ==like=>> 366
# 411 /1000
# 411 ==like=>> 389
# 411 ==like=>> 400
# 411 ==like=>> 290
# 411 ==like=>> 4
# 411 ==like=>> 131
# 412 /1000
# 413 /1000
# 413 ==like=>> 391
# 413 ==like=>> 424
# 414 /1000
# 415 /1000
# 416 /1000
# 416 ==like=>> 20
# 416 ==like=>> 339
# 416 ==like=>> 292
# 416 ==like=>> 75
# 416 ==like=>> 262
# 417 /1000
# 417 ==like=>> 10
# 417 ==like=>> 390
# 417 ==like=>> 67
# 417 ==like=>> 274
# 417 ==like=>> 61
# 417 ==like=>> 314
# 418 /1000
# 418 ==like=>> 0
# 418 ==like=>> 32
# 418 ==like=>> 59
# 419 /1000
# 419 ==like=>> 276
# 419 ==like=>> 309
# 419 ==like=>> 254
# 419 ==like=>> 408
# 420 /1000
# 421 /1000
# 422 /1000
# 422 ==like=>> 26
# 422 ==like=>> 268
# 422 ==like=>> 81
# 422 ==like=>> 135
# 422 ==like=>> 257
# 422 ==like=>> 4
# 422 ==like=>> 131
# 422 ==like=>> 246
# 422 ==like=>> 191
# 422 ==like=>> 213
# 422 ==like=>> 334
# 422 ==like=>> 345
# 422 ==like=>> 433
# 422 ==like=>> 125
# 422 ==like=>> 356
# 422 ==like=>> 312
# 423 /1000
# 424 /1000
# 424 ==like=>> 413
# 425 /1000
# 426 /1000
# 426 ==like=>> 382
# 426 ==like=>> 320
# 427 /1000
# 427 ==like=>> 350
# 427 ==like=>> 339
# 427 ==like=>> 152
# 427 ==like=>> 251
# 427 ==like=>> 64
# 427 ==like=>> 405
# 427 ==like=>> 416
# 427 ==like=>> 9
# 427 ==like=>> 336
# 428 /1000
# 429 /1000
# 429 ==like=>> 328
# 429 ==like=>> 110
# 429 ==like=>> 154
# 430 /1000
# 430 ==like=>> 254
# 430 ==like=>> 111
# 430 ==like=>> 397
# 430 ==like=>> 59
# 430 ==like=>> 122
# 430 ==like=>> 188
# 430 ==like=>> 276
# 430 ==like=>> 419
# 430 ==like=>> 199
# 430 ==like=>> 408
# 430 ==like=>> 1
# 430 ==like=>> 43
# 431 /1000
# 432 /1000
# 432 ==like=>> 288
# 432 ==like=>> 212
# 433 /1000
# 433 ==like=>> 4
# 433 ==like=>> 131
# 433 ==like=>> 345
# 433 ==like=>> 301
# 433 ==like=>> 323
# 433 ==like=>> 422
# 434 /1000
# 434 ==like=>> 272
# 434 ==like=>> 418
# 434 ==like=>> 49
# 434 ==like=>> 320
# 434 ==like=>> 39
# 435 /1000
# 435 ==like=>> 6
# 435 ==like=>> 19
# 435 ==like=>> 53
# 435 ==like=>> 219
# 435 ==like=>> 424
# 436 /1000
# 437 /1000
# 437 ==like=>> 360
# 438 /1000
# 438 ==like=>> 229
# 438 ==like=>> 9
# 438 ==like=>> 336
# 439 /1000
# 440 /1000
# 440 ==like=>> 106
# 440 ==like=>> 164
# 440 ==like=>> 8
# 440 ==like=>> 72
# 440 ==like=>> 117
# 440 ==like=>> 39
# 440 ==like=>> 371
# 440 ==like=>> 6
# 440 ==like=>> 19
# 440 ==like=>> 53
# 440 ==like=>> 219
# 441 /1000
# 442 /1000
# 442 ==like=>> 431
# 443 /1000
# 443 ==like=>> 25
# 443 ==like=>> 59
# 443 ==like=>> 102
# 443 ==like=>> 344
# 443 ==like=>> 234
# 443 ==like=>> 3
# 443 ==like=>> 120
# 443 ==like=>> 157
# 443 ==like=>> 278
# 443 ==like=>> 367
# 444 /1000
# 444 ==like=>> 70
# 444 ==like=>> 81
# 444 ==like=>> 4
# 444 ==like=>> 131
# 444 ==like=>> 333
# 444 ==like=>> 157
# 444 ==like=>> 312
# 444 ==like=>> 125
# 444 ==like=>> 345
# 444 ==like=>> 422
# 444 ==like=>> 334
# 444 ==like=>> 433
# 445 /1000
# 445 ==like=>> 153
# 445 ==like=>> 7
# 445 ==like=>> 28
# 445 ==like=>> 6
# 445 ==like=>> 19
# 445 ==like=>> 53
# 445 ==like=>> 219
# 445 ==like=>> 314
# 446 /1000
# 446 ==like=>> 6
# 446 ==like=>> 19
# 446 ==like=>> 53
# 446 ==like=>> 219
# 446 ==like=>> 348
# 446 ==like=>> 216
# 447 /1000
# 447 ==like=>> 318
# 447 ==like=>> 59
# 448 /1000
# 448 ==like=>> 439
# 448 ==like=>> 382
# 448 ==like=>> 173
# 448 ==like=>> 96
# 448 ==like=>> 153
# 448 ==like=>> 250
# 448 ==like=>> 294
# 448 ==like=>> 261
# 448 ==like=>> 217
# 448 ==like=>> 195
# 448 ==like=>> 228
# 448 ==like=>> 349
# 448 ==like=>> 239
# 448 ==like=>> 8
# 448 ==like=>> 72
# 448 ==like=>> 206
# 448 ==like=>> 52
# 448 ==like=>> 440
# 448 ==like=>> 49
# 448 ==like=>> 137
# 448 ==like=>> 437

# %%
pd.DataFrame(list_edge).to_csv("B_nw_25day.csv")

# %%
len(list_edge)
# Out:
# 858

# %%
dd=pd.read_csv("B_nw_25day.csv").drop("Unnamed: 0",axis=1)
dd.head()
# Out:
#    0   1
# 0  0  11
# 1  0  33
# 2  0  44
# 3  0  55
# 4  0  66

# %%
dd.shape
# Out:
# (858, 2)
